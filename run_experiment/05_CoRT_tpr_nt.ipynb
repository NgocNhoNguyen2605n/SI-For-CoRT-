# %% [markdown]
# # TPR Experiment for Adaptive CoRT-SI across different nT
# This notebook tests the true positive rate (TPR) of Adaptive CoRT-SI across varying target sample sizes (`nT`). It supports resumability, meaning if the execution is interrupted, it can pick up exactly where it left off by reading the saved `.npz` files.

# %%
from pathlib import Path
import sys

import numpy as np

cwd = Path.cwd().resolve()
candidates = [cwd, cwd.parent]
REPO_ROOT = next((candidate for candidate in candidates if (candidate / "cort_si").exists()), None)
if REPO_ROOT is None:
    raise RuntimeError("Could not locate the repo root containing the cort_si package.")
if str(REPO_ROOT) not in sys.path:
    sys.path.insert(0, str(REPO_ROOT))

from cort_si import SI_parallel_randj, SI_randj, gen_data

RESULTS_DIR = REPO_ROOT / "run_experiment" / "results"
RESULTS_DIR.mkdir(parents=True, exist_ok=True)

# %%
# %load_ext autoreload
# %autoreload 2

# %%
p = 300
nS = 100
num_info_aux = 3
num_uninfo_aux = 2
K = num_info_aux + num_uninfo_aux
lambda_sel = 0.8
lambda0 = 1
T = 5
nT_list = [50, 75, 100]

num_runs = 1000
base_seed = 0
alpha = 0.05
true_beta_scale = 1.0
rho = 0.0
sigma_noise = 1.0
source_shift_sd = 0.3
covariate_shift = False
save_interval = 1
verbose = False

print(f"num_runs = {num_runs}")
print(f"fixed alpha = {alpha}")
print(f"Null model true_beta scale = {true_beta_scale}")
print(f"K = {K}, p = {p}, nS = {nS}")
print(f"Testing nT values: {nT_list}")
# Out:
# num_runs = 1000
# fixed alpha = 0.05
# Null model true_beta scale = 1.0
# K = 5, p = 300, nS = 100
# Testing nT values: [50, 75, 100]

# %%
def generate_null_instance(nT_val, iteration_seed):
    return gen_data.generate_data(
        p=p,
        nS=nS,
        nT=nT_val,
        K=K,
        true_beta=true_beta_scale,
        rho=rho,
        sigma_noise=sigma_noise,
        source_shift_sd=source_shift_sd,
        covariate_shift=covariate_shift,
        seed=iteration_seed,
        num_info_aux=num_info_aux,
        num_uninfo_aux= num_uninfo_aux
    )

def get_save_path(p_val, nS_val, nT_val, K, lambda_sel, lambda0):
    return RESULTS_DIR / f"CoRT_tpr_p{p_val}_nS{nS_val}_nT{nT_val}_K{K}_lamsel{lambda_sel}_lam0{lambda0}.npz"

import numpy as np

def load_progress(filepath):
    if filepath.exists():
        data = np.load(filepath)
        # Hỗ trợ cả file cũ (chỉ có null_pvalues) và file mới (có thêm j_values)
        if 'j_values' in data and 'null_pvalues' in data:
            return list(data['j_values']), list(data['null_pvalues'])
        elif 'null_pvalues' in data:
            return [], list(data['null_pvalues'])
    return [], []

def save_progress(filepath, j_values, null_pvalues, p_val, nS_val, nT_val, num_runs_val, alpha_val):
    np.savez(
        filepath,
        j_values=np.asarray(j_values, dtype=int),
        null_pvalues=np.asarray(null_pvalues, dtype=float),
        p=np.asarray([p_val], dtype=int),
        nS=np.asarray([nS_val], dtype=int),
        nT=np.asarray([nT_val], dtype=int),
        num_runs=np.asarray([num_runs_val], dtype=int),
        alpha=np.asarray([alpha_val], dtype=float),
    )

# %%
def run_resumable_tpr_experiment(nT_val, total_runs, seed_base, save_intvl=10):
    filepath = get_save_path(p, nS, nT_val, K, lambda_sel, lambda0)
    j_values, null_pvalues = load_progress(filepath)
    start_iteration = len(null_pvalues)
    
    if start_iteration >= total_runs:
        print(f"Experiment for nT={nT_val} already completed ({total_runs} runs).")
        return j_values, null_pvalues
    
    print(f"Starting/Resuming experiment for nT={nT_val} from run {start_iteration}/{total_runs}...")
    cnt = 0
    sum = 0
    for iteration in range(start_iteration, total_runs):
        data_seed = seed_base + iteration
        XS_list, YS_list, X0, Y0, _, SigmaS_list, Sigma0, _ = generate_null_instance(nT_val, data_seed)
        lambdak_list = [lambda0] * len(XS_list)

        # SI_parallel_randj giờ trả về (j, p_sel) hoặc None
        result = SI_parallel_randj(
            X0,
            Y0,
            XS_list,
            YS_list,
            lambda_sel=lambda_sel,
            lambda0=lambda0,
            lambdak_list=lambdak_list,
            SigmaS_list=SigmaS_list,
            Sigma0=Sigma0,
            T=T,
            verbose=verbose,
        )

        if result is not None:
            j_val, p_sel = result
            if p_sel is not None and np.isfinite(p_sel):
                if j_val <= 5:
                    if p_sel <= alpha:
                        cnt += 1
                    sum += 1
                j_values.append(int(j_val))
                null_pvalues.append(float(p_sel))

        if (iteration + 1) % save_intvl == 0 or (iteration + 1) == total_runs:
            save_progress(filepath, j_values, null_pvalues, p, nS, nT_val, total_runs, alpha)
            print(f"  [nT={nT_val}] Saved progress: {iteration + 1}/{total_runs} runs completed.")
            if sum > 0:
                print(f"Empirical TPR @ alpha={alpha}: {(cnt / sum):.3f} | total run : {sum}")

    return j_values, null_pvalues

# %%
import gc
for current_nT in nT_list:
    run_resumable_tpr_experiment(current_nT, num_runs, base_seed, save_intvl=save_interval)
    gc.collect()
# Out:
# Starting/Resuming experiment for nT=50 from run 139/1000...
#   [nT=50] Saved progress: 140/1000 runs completed.
# Empirical TPR @ alpha=0.05: 0.000 | total run : 1
#   [nT=50] Saved progress: 141/1000 runs completed.
# Empirical TPR @ alpha=0.05: 0.000 | total run : 2
#   [nT=50] Saved progress: 142/1000 runs completed.
# Empirical TPR @ alpha=0.05: 0.333 | total run : 3
#   [nT=50] Saved progress: 143/1000 runs completed.
# Empirical TPR @ alpha=0.05: 0.250 | total run : 4
#   [nT=50] Saved progress: 144/1000 runs completed.
# Empirical TPR @ alpha=0.05: 0.400 | total run : 5
#   [nT=50] Saved progress: 145/1000 runs completed.
# Empirical TPR @ alpha=0.05: 0.333 | total run : 6
#   [nT=50] Saved progress: 146/1000 runs completed.
# Empirical TPR @ alpha=0.05: 0.286 | total run : 7
#   [nT=50] Saved progress: 147/1000 runs completed.
# Empirical TPR @ alpha=0.05: 0.375 | total run : 8
#   [nT=50] Saved progress: 148/1000 runs completed.
# Empirical TPR @ alpha=0.05: 0.333 | total run : 9
#   [nT=50] Saved progress: 149/1000 runs completed.
# Empirical TPR @ alpha=0.05: 0.300 | total run : 10
#   [nT=50] Saved progress: 150/1000 runs completed.
# Empirical TPR @ alpha=0.05: 0.273 | total run : 11
#   [nT=50] Saved progress: 151/1000 runs completed.
# Empirical TPR @ alpha=0.05: 0.250 | total run : 12
#   [nT=50] Saved progress: 152/1000 runs completed.
# Empirical TPR @ alpha=0.05: 0.231 | total run : 13
#   [nT=50] Saved progress: 153/1000 runs completed.
# Empirical TPR @ alpha=0.05: 0.214 | total run : 14
#   [nT=50] Saved progress: 154/1000 runs completed.
# Empirical TPR @ alpha=0.05: 0.200 | total run : 15
#   [nT=50] Saved progress: 155/1000 runs completed.
# Empirical TPR @ alpha=0.05: 0.188 | total run : 16
#   [nT=50] Saved progress: 156/1000 runs completed.
# Empirical TPR @ alpha=0.05: 0.235 | total run : 17
#   [nT=50] Saved progress: 157/1000 runs completed.
# Empirical TPR @ alpha=0.05: 0.278 | total run : 18
#   [nT=50] Saved progress: 158/1000 runs completed.
# Empirical TPR @ alpha=0.05: 0.263 | total run : 19
#   [nT=50] Saved progress: 159/1000 runs completed.
# Empirical TPR @ alpha=0.05: 0.300 | total run : 20
#   [nT=50] Saved progress: 160/1000 runs completed.
# Empirical TPR @ alpha=0.05: 0.333 | total run : 21
#   [nT=50] Saved progress: 161/1000 runs completed.
# Empirical TPR @ alpha=0.05: 0.333 | total run : 21
#   [nT=50] Saved progress: 162/1000 runs completed.
# Empirical TPR @ alpha=0.05: 0.318 | total run : 22
#   [nT=50] Saved progress: 163/1000 runs completed.
# Empirical TPR @ alpha=0.05: 0.304 | total run : 23
#   [nT=50] Saved progress: 164/1000 runs completed.
# Empirical TPR @ alpha=0.05: 0.292 | total run : 24
#   [nT=50] Saved progress: 165/1000 runs completed.
# Empirical TPR @ alpha=0.05: 0.320 | total run : 25
#   [nT=50] Saved progress: 166/1000 runs completed.
# Empirical TPR @ alpha=0.05: 0.320 | total run : 25
#   [nT=50] Saved progress: 167/1000 runs completed.
# Empirical TPR @ alpha=0.05: 0.308 | total run : 26
#   [nT=50] Saved progress: 168/1000 runs completed.
# Empirical TPR @ alpha=0.05: 0.296 | total run : 27
#   [nT=50] Saved progress: 169/1000 runs completed.
# Empirical TPR @ alpha=0.05: 0.286 | total run : 28
#   [nT=50] Saved progress: 170/1000 runs completed.
# Empirical TPR @ alpha=0.05: 0.276 | total run : 29
#   [nT=50] Saved progress: 171/1000 runs completed.
# Empirical TPR @ alpha=0.05: 0.300 | total run : 30
#   [nT=50] Saved progress: 172/1000 runs completed.
# Empirical TPR @ alpha=0.05: 0.290 | total run : 31
#   [nT=50] Saved progress: 173/1000 runs completed.
# Empirical TPR @ alpha=0.05: 0.281 | total run : 32
#   [nT=50] Saved progress: 174/1000 runs completed.
# Empirical TPR @ alpha=0.05: 0.303 | total run : 33
#   [nT=50] Saved progress: 175/1000 runs completed.
# Empirical TPR @ alpha=0.05: 0.324 | total run : 34
#   [nT=50] Saved progress: 176/1000 runs completed.
# Empirical TPR @ alpha=0.05: 0.324 | total run : 34
#   [nT=50] Saved progress: 177/1000 runs completed.
# Empirical TPR @ alpha=0.05: 0.314 | total run : 35
#   [nT=50] Saved progress: 178/1000 runs completed.
# Empirical TPR @ alpha=0.05: 0.306 | total run : 36
#   [nT=50] Saved progress: 179/1000 runs completed.
# Empirical TPR @ alpha=0.05: 0.297 | total run : 37
#   [nT=50] Saved progress: 180/1000 runs completed.
# Empirical TPR @ alpha=0.05: 0.289 | total run : 38
#   [nT=50] Saved progress: 181/1000 runs completed.
# Empirical TPR @ alpha=0.05: 0.308 | total run : 39
#   [nT=50] Saved progress: 182/1000 runs completed.
# Empirical TPR @ alpha=0.05: 0.300 | total run : 40
#   [nT=50] Saved progress: 183/1000 runs completed.
# Empirical TPR @ alpha=0.05: 0.293 | total run : 41
#   [nT=50] Saved progress: 184/1000 runs completed.
# Empirical TPR @ alpha=0.05: 0.310 | total run : 42
#   [nT=50] Saved progress: 185/1000 runs completed.
# Empirical TPR @ alpha=0.05: 0.302 | total run : 43
#   [nT=50] Saved progress: 186/1000 runs completed.
# Empirical TPR @ alpha=0.05: 0.318 | total run : 44
#   [nT=50] Saved progress: 187/1000 runs completed.
# Empirical TPR @ alpha=0.05: 0.311 | total run : 45
#   [nT=50] Saved progress: 188/1000 runs completed.
# Empirical TPR @ alpha=0.05: 0.304 | total run : 46
#   [nT=50] Saved progress: 189/1000 runs completed.
# Empirical TPR @ alpha=0.05: 0.298 | total run : 47
#   [nT=50] Saved progress: 190/1000 runs completed.
# Empirical TPR @ alpha=0.05: 0.312 | total run : 48
#   [nT=50] Saved progress: 191/1000 runs completed.
# Empirical TPR @ alpha=0.05: 0.306 | total run : 49
#   [nT=50] Saved progress: 192/1000 runs completed.
# Empirical TPR @ alpha=0.05: 0.300 | total run : 50
#   [nT=50] Saved progress: 193/1000 runs completed.
# Empirical TPR @ alpha=0.05: 0.294 | total run : 51
#   [nT=50] Saved progress: 194/1000 runs completed.
# Empirical TPR @ alpha=0.05: 0.288 | total run : 52
#   [nT=50] Saved progress: 195/1000 runs completed.
# Empirical TPR @ alpha=0.05: 0.288 | total run : 52
#   [nT=50] Saved progress: 196/1000 runs completed.
# Empirical TPR @ alpha=0.05: 0.283 | total run : 53
#   [nT=50] Saved progress: 197/1000 runs completed.
# Empirical TPR @ alpha=0.05: 0.296 | total run : 54
#   [nT=50] Saved progress: 198/1000 runs completed.
# Empirical TPR @ alpha=0.05: 0.309 | total run : 55
#   [nT=50] Saved progress: 199/1000 runs completed.
# Empirical TPR @ alpha=0.05: 0.304 | total run : 56
#   [nT=50] Saved progress: 200/1000 runs completed.
# Empirical TPR @ alpha=0.05: 0.298 | total run : 57
#   [nT=50] Saved progress: 201/1000 runs completed.
# Empirical TPR @ alpha=0.05: 0.293 | total run : 58
#   [nT=50] Saved progress: 202/1000 runs completed.
# Empirical TPR @ alpha=0.05: 0.288 | total run : 59
#   [nT=50] Saved progress: 203/1000 runs completed.
# Empirical TPR @ alpha=0.05: 0.300 | total run : 60
#   [nT=50] Saved progress: 204/1000 runs completed.
# Empirical TPR @ alpha=0.05: 0.295 | total run : 61
#   [nT=50] Saved progress: 205/1000 runs completed.
# Empirical TPR @ alpha=0.05: 0.290 | total run : 62
#   [nT=50] Saved progress: 206/1000 runs completed.
# Empirical TPR @ alpha=0.05: 0.286 | total run : 63
#   [nT=50] Saved progress: 207/1000 runs completed.
# Empirical TPR @ alpha=0.05: 0.281 | total run : 64
#   [nT=50] Saved progress: 208/1000 runs completed.
# Empirical TPR @ alpha=0.05: 0.292 | total run : 65
#   [nT=50] Saved progress: 209/1000 runs completed.
# Empirical TPR @ alpha=0.05: 0.288 | total run : 66
#   [nT=50] Saved progress: 210/1000 runs completed.
# Empirical TPR @ alpha=0.05: 0.299 | total run : 67
#   [nT=50] Saved progress: 211/1000 runs completed.
# Empirical TPR @ alpha=0.05: 0.294 | total run : 68
#   [nT=50] Saved progress: 212/1000 runs completed.
# Empirical TPR @ alpha=0.05: 0.290 | total run : 69
#   [nT=50] Saved progress: 213/1000 runs completed.
# Empirical TPR @ alpha=0.05: 0.286 | total run : 70
#   [nT=50] Saved progress: 214/1000 runs completed.
# Empirical TPR @ alpha=0.05: 0.282 | total run : 71
#   [nT=50] Saved progress: 215/1000 runs completed.
# Empirical TPR @ alpha=0.05: 0.278 | total run : 72
#   [nT=50] Saved progress: 216/1000 runs completed.
# Empirical TPR @ alpha=0.05: 0.288 | total run : 73
#   [nT=50] Saved progress: 217/1000 runs completed.
# Empirical TPR @ alpha=0.05: 0.284 | total run : 74
#   [nT=50] Saved progress: 218/1000 runs completed.
# Empirical TPR @ alpha=0.05: 0.280 | total run : 75
#   [nT=50] Saved progress: 219/1000 runs completed.
# Empirical TPR @ alpha=0.05: 0.276 | total run : 76
#   [nT=50] Saved progress: 220/1000 runs completed.
# Empirical TPR @ alpha=0.05: 0.273 | total run : 77
#   [nT=50] Saved progress: 221/1000 runs completed.
# Empirical TPR @ alpha=0.05: 0.282 | total run : 78
#   [nT=50] Saved progress: 222/1000 runs completed.
# Empirical TPR @ alpha=0.05: 0.278 | total run : 79
#   [nT=50] Saved progress: 223/1000 runs completed.
# Empirical TPR @ alpha=0.05: 0.275 | total run : 80
#   [nT=50] Saved progress: 224/1000 runs completed.
# Empirical TPR @ alpha=0.05: 0.284 | total run : 81
#   [nT=50] Saved progress: 225/1000 runs completed.
# Empirical TPR @ alpha=0.05: 0.293 | total run : 82
#   [nT=50] Saved progress: 226/1000 runs completed.
# Empirical TPR @ alpha=0.05: 0.301 | total run : 83
#   [nT=50] Saved progress: 227/1000 runs completed.
# Empirical TPR @ alpha=0.05: 0.298 | total run : 84
#   [nT=50] Saved progress: 228/1000 runs completed.
# Empirical TPR @ alpha=0.05: 0.298 | total run : 84
#   [nT=50] Saved progress: 229/1000 runs completed.
# Empirical TPR @ alpha=0.05: 0.294 | total run : 85
#   [nT=50] Saved progress: 230/1000 runs completed.
# Empirical TPR @ alpha=0.05: 0.291 | total run : 86
#   [nT=50] Saved progress: 231/1000 runs completed.
# Empirical TPR @ alpha=0.05: 0.299 | total run : 87
#   [nT=50] Saved progress: 232/1000 runs completed.
# Empirical TPR @ alpha=0.05: 0.295 | total run : 88
#   [nT=50] Saved progress: 233/1000 runs completed.
# Empirical TPR @ alpha=0.05: 0.303 | total run : 89
#   [nT=50] Saved progress: 234/1000 runs completed.
# Empirical TPR @ alpha=0.05: 0.311 | total run : 90
#   [nT=50] Saved progress: 235/1000 runs completed.
# Empirical TPR @ alpha=0.05: 0.308 | total run : 91
#   [nT=50] Saved progress: 236/1000 runs completed.
# Empirical TPR @ alpha=0.05: 0.304 | total run : 92
#   [nT=50] Saved progress: 237/1000 runs completed.
# Empirical TPR @ alpha=0.05: 0.312 | total run : 93
#   [nT=50] Saved progress: 238/1000 runs completed.
# Empirical TPR @ alpha=0.05: 0.319 | total run : 94
#   [nT=50] Saved progress: 239/1000 runs completed.
# Empirical TPR @ alpha=0.05: 0.316 | total run : 95
#   [nT=50] Saved progress: 240/1000 runs completed.
# Empirical TPR @ alpha=0.05: 0.312 | total run : 96
#   [nT=50] Saved progress: 241/1000 runs completed.
# Empirical TPR @ alpha=0.05: 0.320 | total run : 97
#   [nT=50] Saved progress: 242/1000 runs completed.
# Empirical TPR @ alpha=0.05: 0.316 | total run : 98
#   [nT=50] Saved progress: 243/1000 runs completed.
# Empirical TPR @ alpha=0.05: 0.323 | total run : 99
#   [nT=50] Saved progress: 244/1000 runs completed.
# Empirical TPR @ alpha=0.05: 0.330 | total run : 100
#   [nT=50] Saved progress: 245/1000 runs completed.
# Empirical TPR @ alpha=0.05: 0.327 | total run : 101
#   [nT=50] Saved progress: 246/1000 runs completed.
# Empirical TPR @ alpha=0.05: 0.324 | total run : 102
#   [nT=50] Saved progress: 247/1000 runs completed.
# Empirical TPR @ alpha=0.05: 0.320 | total run : 103
#   [nT=50] Saved progress: 248/1000 runs completed.
# Empirical TPR @ alpha=0.05: 0.317 | total run : 104
#   [nT=50] Saved progress: 249/1000 runs completed.
# Empirical TPR @ alpha=0.05: 0.324 | total run : 105
#   [nT=50] Saved progress: 250/1000 runs completed.
# Empirical TPR @ alpha=0.05: 0.330 | total run : 106
#   [nT=50] Saved progress: 251/1000 runs completed.
# Empirical TPR @ alpha=0.05: 0.327 | total run : 107
#   [nT=50] Saved progress: 252/1000 runs completed.
# Empirical TPR @ alpha=0.05: 0.324 | total run : 108
#   [nT=50] Saved progress: 253/1000 runs completed.
# Empirical TPR @ alpha=0.05: 0.321 | total run : 109
#   [nT=50] Saved progress: 254/1000 runs completed.
# Empirical TPR @ alpha=0.05: 0.327 | total run : 110
#   [nT=50] Saved progress: 255/1000 runs completed.
# Empirical TPR @ alpha=0.05: 0.333 | total run : 111
#   [nT=50] Saved progress: 256/1000 runs completed.
# Empirical TPR @ alpha=0.05: 0.330 | total run : 112
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 3
#       1 import gc
#       2 for current_nT in nT_list:
# ----> 3     run_resumable_tpr_experiment(current_nT, num_runs, base_seed, save_intvl=save_interval)
#       4     gc.collect()
#
# Cell In[5], line 19, in run_resumable_tpr_experiment(nT_val, total_runs, seed_base, save_intvl)
#      16 lambdak_list = [lambda0] * len(XS_list)
#      18 # SI_parallel_randj giờ trả về (j, p_sel) hoặc None
# ---> 19 result = SI_parallel_randj(
#      20     X0,
#      21     Y0,
#      22     XS_list,
#      23     YS_list,
#      24     lambda_sel=lambda_sel,
#      25     lambda0=lambda0,
#      26     lambdak_list=lambdak_list,
#      27     SigmaS_list=SigmaS_list,
#      28     Sigma0=Sigma0,
#      29     T=T,
#      30     verbose=verbose,
#      31 )
#      33 if result is not None:
#      34     j_val, p_sel = result
#
# File D:\Data_Science_Project\nho_CoRT\SI-For-CoRT-\cort_si\CORT_SI.py:204, in SI_parallel_randj(X0, Y0, XS_list, YS_list, lambda_sel, lambda0, lambdak_list, SigmaS_list, Sigma0, folds, T, z_min, z_max, verbose)
#     202 z_points = np.linspace(z_min, z_max, S + 1)
#     203 sub_intervals = [(z_points[i], z_points[i+1]) for i in range(S)]
# --> 204 parallel_results_source = Parallel(n_jobs=S)(
#     205     delayed(sub_prob.compute_Z1_region)(
#     206         X0, Y0, XS_list, YS_list, a, b, folds, I_obs, lambda_sel, z_start, z_end
#     207     ) for z_start, z_end in sub_intervals
#     208 )
#     209 intervals_source = [interval for sublist in parallel_results_source if sublist for interval in sublist]
#     210 intervals_model = sub_prob.compute_Z2_region(
#     211     X0, Y0, XS_list, YS_list, a, b, I_obs, M_obs,
#     212     intervals_source, lambda0, lambdak_list
#     213 )
#
# File c:\Users\Hiep\AppData\Local\Programs\Python\Python312\Lib\site-packages\joblib\parallel.py:2072, in Parallel.__call__(self, iterable)
#    2066 # The first item from the output is blank, but it makes the interpreter
#    2067 # progress until it enters the Try/Except block of the generator and
#    2068 # reaches the first `yield` statement. This starts the asynchronous
#    2069 # dispatch of the tasks to the workers.
#    2070 next(output)
# -> 2072 return output if self.return_generator else list(output)
#
# File c:\Users\Hiep\AppData\Local\Programs\Python\Python312\Lib\site-packages\joblib\parallel.py:1682, in Parallel._get_outputs(self, iterator, pre_dispatch)
#    1679     yield
#    1681     with self._backend.retrieval_context():
# -> 1682         yield from self._retrieve()
#    1684 except GeneratorExit:
#    1685     # The generator has been garbage collected before being fully
#    1686     # consumed. This aborts the remaining tasks if possible and warn
#    1687     # the user if necessary.
#    1688     self._exception = True
#
# File c:\Users\Hiep\AppData\Local\Programs\Python\Python312\Lib\site-packages\joblib\parallel.py:1800, in Parallel._retrieve(self)
#    1789 if self.return_ordered:
#    1790     # Case ordered: wait for completion (or error) of the next job
#    1791     # that have been dispatched and not retrieved yet. If no job
#    (...)   1795     # control only have to be done on the amount of time the next
#    1796     # dispatched job is pending.
#    1797     if (nb_jobs == 0) or (
#    1798         self._jobs[0].get_status(timeout=self.timeout) == TASK_PENDING
#    1799     ):
# -> 1800         time.sleep(0.01)
#    1801         continue
#    1803 elif nb_jobs == 0:
#    1804     # Case unordered: jobs are added to the list of jobs to
#    1805     # retrieve `self._jobs` only once completed or in error, which
#    (...)   1811     # timeouts before any other dispatched job has completed and
#    1812     # been added to `self._jobs` to be retrieved.
#
# KeyboardInterrupt:

# %%
print("=== TPR Experiment Summary ===")
for current_nT in nT_list:
    filepath = get_save_path(p, nS, current_nT, K, lambda_sel, lambda0)
    j_values, pvals = load_progress(filepath)
    
    if not pvals:
        print(f"nT={current_nT}: No data found.")
        continue
    
    pvals_arr = np.asarray(pvals)
    # Tính TPR: tỉ lệ số lần p-value <= alpha
    rejection_rate = (pvals_arr <= alpha).mean()
    print(f"nT={current_nT}: {len(pvals)} valid runs | Empirical TPR @ alpha={alpha}: {rejection_rate:.3f}")
# Out:
# === FPR Experiment Summary ===
# nT=50: 222 valid runs | Empirical FPR @ alpha=0.05: 0.302
# nT=75: No data found.
# nT=100: No data found.
