# %% [markdown]
# # TPR Experiment for Adaptive CoRT-SI across different nT
# This notebook tests the false positive rate (TPR) of Adaptive CoRT-SI across varying target sample sizes (`nT`). It supports resumability, meaning if the execution is interrupted, it can pick up exactly where it left off by reading the saved `.npz` files.

# %%
from pathlib import Path
import sys

import numpy as np

cwd = Path.cwd().resolve()
candidates = [cwd, cwd.parent]
REPO_ROOT = next((candidate for candidate in candidates if (candidate / "cort_si").exists()), None)
if REPO_ROOT is None:
    raise RuntimeError("Could not locate the repo root containing the cort_si package.")
if str(REPO_ROOT) not in sys.path:
    sys.path.insert(0, str(REPO_ROOT))

from cort_si import SI_parallel_randj, SI_randj, gen_data

RESULTS_DIR = REPO_ROOT / "run_experiment" / "results"
RESULTS_DIR.mkdir(parents=True, exist_ok=True)

# %%
p = 300
nS = 100
num_info_aux = 3
num_uninfo_aux = 2
K = num_info_aux + num_uninfo_aux
lambda_sel = 0.8
lambda0 = 0.8
T = 5
nT_list = [50, 75, 100]

num_runs = 1000
base_seed = 0
alpha = 0.05
true_beta_scale = 1.0
rho = 0.0
sigma_noise = 1.0
source_shift_sd = 0.3
covariate_shift = False
save_interval = 1

print(f"num_runs = {num_runs}")
print(f"fixed alpha = {alpha}")
print(f"Null model true_beta scale = {true_beta_scale}")
print(f"K = {K}, p = {p}, nS = {nS}")
print(f"Testing nT values: {nT_list}")
# Out:
# num_runs = 1000
# fixed alpha = 0.05
# Null model true_beta scale = 1.0
# K = 5, p = 300, nS = 100
# Testing nT values: [50, 75, 100]

# %%
def generate_null_instance(nT_val, iteration_seed):
    return gen_data.generate_data(
        p=p,
        nS=nS,
        nT=nT_val,
        K=K,
        true_beta=true_beta_scale,
        rho=rho,
        sigma_noise=sigma_noise,
        source_shift_sd=source_shift_sd,
        covariate_shift=covariate_shift,
        seed=iteration_seed,
        num_info_aux=num_info_aux,
        num_uninfo_aux= num_uninfo_aux
    )

def get_save_path(p_val, nS_val, nT_val, K, lambda_sel, lambda0):
    return RESULTS_DIR / f"CoRT_tpr_p{p_val}_nS{nS_val}_nT{nT_val}_K{K}_lamsel{lambda_sel}_lam0{lambda0}.npz"

import numpy as np

def load_progress(filepath):
    if filepath.exists():
        data = np.load(filepath)
        # Hỗ trợ cả file cũ (chỉ có null_pvalues) và file mới (có thêm j_values)
        if 'j_values' in data and 'null_pvalues' in data:
            return list(data['j_values']), list(data['null_pvalues'])
        elif 'null_pvalues' in data:
            return [], list(data['null_pvalues'])
    return [], []

def save_progress(filepath, j_values, null_pvalues, p_val, nS_val, nT_val, num_runs_val, alpha_val):
    np.savez(
        filepath,
        j_values=np.asarray(j_values, dtype=int),
        null_pvalues=np.asarray(null_pvalues, dtype=float),
        p=np.asarray([p_val], dtype=int),
        nS=np.asarray([nS_val], dtype=int),
        nT=np.asarray([nT_val], dtype=int),
        num_runs=np.asarray([num_runs_val], dtype=int),
        alpha=np.asarray([alpha_val], dtype=float),
    )

# %%
def run_resumable_TPR_experiment(nT_val, total_runs, seed_base, save_intvl=10):
    filepath = get_save_path(p, nS, nT_val, K, lambda_sel, lambda0)
    j_values, null_pvalues = load_progress(filepath)
    start_iteration = len(null_pvalues)
    
    if start_iteration >= total_runs:
        print(f"Experiment for nT={nT_val} already completed ({total_runs} runs).")
        return j_values, null_pvalues
    
    print(f"Starting/Resuming experiment for nT={nT_val} from run {start_iteration}/{total_runs}...")
    cnt = 0
    sum = 0
    mau = 0
    for iteration in range(start_iteration, total_runs):
        data_seed = seed_base + iteration
        XS_list, YS_list, X0, Y0, _, SigmaS_list, Sigma0, _ = generate_null_instance(nT_val, data_seed)
        lambdak_list = [lambda0] * len(XS_list)

        # SI_parallel_randj giờ trả về (j, p_sel) hoặc None
        result = SI_parallel_randj(
            X0,
            Y0,
            XS_list,
            YS_list,
            lambda_sel=lambda_sel,
            lambda0=lambda0,
            lambdak_list=lambdak_list,
            SigmaS_list=SigmaS_list,
            Sigma0=Sigma0,
            T=T,
            verbose=False,
        )

        if result is not None:
            j_val, p_sel = result
            if p_sel is not None and np.isfinite(p_sel):
                if j_val <= 5:
                    if p_sel <= alpha:
                        cnt += 1
                    sum += 1
                mau += 1
                j_values.append(int(j_val))
                null_pvalues.append(float(p_sel))

        if (iteration + 1) % save_intvl == 0 or (iteration + 1) == total_runs:
            save_progress(filepath, j_values, null_pvalues, p, nS, nT_val, total_runs, alpha)
            print(f"  [nT={nT_val}] Saved progress: {iteration + 1}/{total_runs} runs completed.")
            if sum > 0:
                print(f"Empirical TPR @ alpha={alpha}: {(cnt / sum):.3f} | total run : {sum} | cnt: {cnt} | not signal: {mau - sum} ")

    return j_values, null_pvalues

# %%
for current_nT in nT_list:
    run_resumable_TPR_experiment(current_nT, num_runs, base_seed, save_intvl=save_interval)
# Out:
# Starting/Resuming experiment for nT=50 from run 994/1000...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 2
#       1 for current_nT in nT_list:
# ----> 2     run_resumable_TPR_experiment(current_nT, num_runs, base_seed, save_intvl=save_interval)
#
# Cell In[5], line 20, in run_resumable_TPR_experiment(nT_val, total_runs, seed_base, save_intvl)
#      17 lambdak_list = [lambda0] * len(XS_list)
#      19 # SI_parallel_randj giờ trả về (j, p_sel) hoặc None
# ---> 20 result = SI_parallel_randj(
#      21     X0,
#      22     Y0,
#      23     XS_list,
#      24     YS_list,
#      25     lambda_sel=lambda_sel,
#      26     lambda0=lambda0,
#      27     lambdak_list=lambdak_list,
#      28     SigmaS_list=SigmaS_list,
#      29     Sigma0=Sigma0,
#      30     T=T,
#      31     verbose=False,
#      32 )
#      34 if result is not None:
#      35     j_val, p_sel = result
#
# File D:\Data_Science_Project\nho_CoRT\SI-For-CoRT-\cort_si\CORT_SI.py:182, in SI_parallel_randj(X0, Y0, XS_list, YS_list, lambda_sel, lambda0, lambdak_list, SigmaS_list, Sigma0, folds, T, z_min, z_max, verbose)
#     179 if len(folds) % 2 == 0:
#     180     raise ValueError("The number of folds T must be odd")
# --> 182 I_obs = algorithms.adaptive_source_selection(X0, Y0, XS_list, YS_list, folds, lambda_sel, verbose=verbose)
#     183 _, beta0_hat, _, _ = algorithms.solve_cort_model(
#     184     X0, Y0, XS_list, YS_list, I_obs, lambda0, lambdak_list,
#     185     verbose=verbose, label="Observed CoRT fit",
#     186 )
#     187 M_obs = [idx for idx, value in enumerate(beta0_hat) if value != 0]
#
# File D:\Data_Science_Project\nho_CoRT\SI-For-CoRT-\cort_si\algorithms.py:79, in adaptive_source_selection(X0, Y0, XS_list, YS_list, folds, lambda_sel, verbose)
#      77 X_aug_train = np.vstack([Xk, X0_train])
#      78 Y_aug_train = np.concatenate([Yk, Y0_train])
# ---> 79 beta_aug = solve_lasso(
#      80     X_aug_train, Y_aug_train, lambda_sel,
#      81     verbose=verbose, label=f"{fold_tag} target+source",
#      82 )
#      84 loss_target = 0.5 * np.mean((Y0_valid - X0_valid @ beta_target) ** 2)
#      85 loss_aug = 0.5 * np.mean((Y0_valid - X0_valid @ beta_aug) ** 2)
#
# File D:\Data_Science_Project\nho_CoRT\SI-For-CoRT-\cort_si\algorithms.py:20, in solve_lasso(X, y, lam, fit_intercept, tol, max_iter, verbose, label)
#      18 def solve_lasso(X, y, lam, fit_intercept=False, tol=1e-10, max_iter=50000, verbose=False, label=None):
#      19     model = Lasso(alpha=lam, fit_intercept=fit_intercept, tol=tol, max_iter=max_iter)
# ---> 20     model.fit(X, np.asarray(y).ravel())
#      21     coef = model.coef_
#      22     if verbose:
#
# File c:\Users\Hiep\AppData\Local\Programs\Python\Python312\Lib\site-packages\skglm\estimators.py:395, in Lasso.fit(self, X, y)
#     390 # TODO: Add Gram solver
#     391 solver = AndersonCD(
#     392     self.max_iter, self.max_epochs, self.p0, tol=self.tol,
#     393     ws_strategy=self.ws_strategy, fit_intercept=self.fit_intercept,
#     394     warm_start=self.warm_start, verbose=self.verbose)
# --> 395 return _glm_fit(X, y, self, Quadratic(), L1(self.alpha, self.positive), solver)
#
# File c:\Users\Hiep\AppData\Local\Programs\Python\Python312\Lib\site-packages\skglm\estimators.py:132, in _glm_fit(X, y, model, datafit, penalty, solver)
#     127     if len(penalty.weights) != n_features:
#     128         raise ValueError(
#     129             "The size of the WeightedL1 penalty weights should be n_features, "
#     130             "expected %i, got %i." % (X_.shape[1], len(penalty.weights)))
# --> 132 coefs, p_obj, kkt = solver.solve(X_, y, datafit, penalty, w, Xw)
#     133 model.coef_, model.stop_crit_ = coefs[:n_features], kkt
#     134 if y.ndim == 1:
#
# File c:\Users\Hiep\AppData\Local\Programs\Python\Python312\Lib\site-packages\skglm\solvers\base.py:136, in BaseSolver.solve(self, X, y, datafit, penalty, w_init, Xw_init, run_checks)
#     133 if run_checks:
#     134     self._validate(X, y, datafit, penalty)
# --> 136 return self._solve(X, y, datafit, penalty, w_init, Xw_init)
#
# File c:\Users\Hiep\AppData\Local\Programs\Python\Python312\Lib\site-packages\skglm\solvers\anderson_cd.py:174, in AndersonCD._solve(self, X, y, datafit, penalty, w_init, Xw_init)
#     169 w_acc[ws_intercept], Xw_acc[:], is_extrap = accelerator.extrapolate(
#     170     w[ws_intercept], Xw)
#     172 if is_extrap:  # avoid computing p_obj for un-extrapolated w, Xw
#     173     # TODO : manage penalty.value(w, ws) for weighted Lasso
# --> 174     p_obj = (datafit.value(y, w[:n_features], Xw) +
#     175              penalty.value(w[:n_features]))
#     176     p_obj_acc = (datafit.value(y, w_acc[:n_features], Xw_acc) +
#     177                  penalty.value(w_acc[:n_features]))
#     179     if p_obj_acc < p_obj:
#
# File c:\Users\Hiep\AppData\Local\Programs\Python\Python312\Lib\site-packages\numba\experimental\jitclass\boxing.py:61, in _generate_method.<locals>.wrapper(*args, **kwargs)
#      59 @wraps(func)
#      60 def wrapper(*args, **kwargs):
# ---> 61     return method(*args, **kwargs)
#
# File c:\Users\Hiep\AppData\Local\Programs\Python\Python312\Lib\site-packages\numba\core\dispatcher.py:376, in _DispatcherBase._compile_for_args(self, *args, **kws)
#     374 return_val = None
#     375 try:
# --> 376     return_val = self.compile(tuple(argtypes))
#     377 except errors.ForceLiteralArg as e:
#     378     # Received request for compiler re-entry with the list of arguments
#     379     # indicated by e.requested_args.
#     380     # First, check if any of these args are already Literal-ized
#     381     already_lit_pos = [i for i in e.requested_args
#     382                        if isinstance(args[i], types.Literal)]
#
# File c:\Users\Hiep\AppData\Local\Programs\Python\Python312\Lib\site-packages\numba\core\dispatcher.py:908, in Dispatcher.compile(self, sig)
#     906 with ev.trigger_event("numba:compile", data=ev_details):
#     907     try:
# --> 908         cres = self._compiler.compile(args, return_type)
#     909     except errors.ForceLiteralArg as e:
#     910         def folded(args, kws):
#
# File c:\Users\Hiep\AppData\Local\Programs\Python\Python312\Lib\site-packages\numba\core\dispatcher.py:80, in _FunctionCompiler.compile(self, args, return_type)
#      79 def compile(self, args, return_type):
# ---> 80     status, retval = self._compile_cached(args, return_type)
#      81     if status:
#      82         return retval
#
# File c:\Users\Hiep\AppData\Local\Programs\Python\Python312\Lib\site-packages\numba\core\dispatcher.py:94, in _FunctionCompiler._compile_cached(self, args, return_type)
#      91     pass
#      93 try:
# ---> 94     retval = self._compile_core(args, return_type)
#      95 except errors.TypingError as e:
#      96     self._failed_cache[key] = e
#
# File c:\Users\Hiep\AppData\Local\Programs\Python\Python312\Lib\site-packages\numba\core\dispatcher.py:107, in _FunctionCompiler._compile_core(self, args, return_type)
#     104 flags = self._customize_flags(flags)
#     106 impl = self._get_implementation(args, {})
# --> 107 cres = compiler.compile_extra(self.targetdescr.typing_context,
#     108                               self.targetdescr.target_context,
#     109                               impl,
#     110                               args=args, return_type=return_type,
#     111                               flags=flags, locals=self.locals,
#     112                               pipeline_class=self.pipeline_class)
#     113 # Check typing error if object mode is used
#     114 if cres.typing_error is not None and not flags.enable_pyobject:
#
# File c:\Users\Hiep\AppData\Local\Programs\Python\Python312\Lib\site-packages\numba\core\compiler.py:739, in compile_extra(typingctx, targetctx, func, args, return_type, flags, locals, library, pipeline_class)
#     715 """Compiler entry point
#     716
#     717 Parameter
#    (...)    735     compiler pipeline
#     736 """
#     737 pipeline = pipeline_class(typingctx, targetctx, library,
#     738                           args, return_type, flags, locals)
# --> 739 return pipeline.compile_extra(func)
#
# File c:\Users\Hiep\AppData\Local\Programs\Python\Python312\Lib\site-packages\numba\core\compiler.py:439, in CompilerBase.compile_extra(self, func)
#     437 self.state.lifted = ()
#     438 self.state.lifted_from = None
# --> 439 return self._compile_bytecode()
#
# File c:\Users\Hiep\AppData\Local\Programs\Python\Python312\Lib\site-packages\numba\core\compiler.py:505, in CompilerBase._compile_bytecode(self)
#     501 """
#     502 Populate and run pipeline for bytecode input
#     503 """
#     504 assert self.state.func_ir is None
# --> 505 return self._compile_core()
#
# File c:\Users\Hiep\AppData\Local\Programs\Python\Python312\Lib\site-packages\numba\core\compiler.py:473, in CompilerBase._compile_core(self)
#     471 res = None
#     472 try:
# --> 473     pm.run(self.state)
#     474     if self.state.cr is not None:
#     475         break
#
# File c:\Users\Hiep\AppData\Local\Programs\Python\Python312\Lib\site-packages\numba\core\compiler_machinery.py:356, in PassManager.run(self, state)
#     354 pass_inst = _pass_registry.get(pss).pass_inst
#     355 if isinstance(pass_inst, CompilerPass):
# --> 356     self._runPass(idx, pass_inst, state)
#     357 else:
#     358     raise BaseException("Legacy pass in use")
#
# File c:\Users\Hiep\AppData\Local\Programs\Python\Python312\Lib\site-packages\numba\core\compiler_lock.py:35, in _CompilerLock.__call__.<locals>._acquire_compile_lock(*args, **kwargs)
#      32 @functools.wraps(func)
#      33 def _acquire_compile_lock(*args, **kwargs):
#      34     with self:
# ---> 35         return func(*args, **kwargs)
#
# File c:\Users\Hiep\AppData\Local\Programs\Python\Python312\Lib\site-packages\numba\core\compiler_machinery.py:311, in PassManager._runPass(self, index, pss, internal_state)
#     309     mutated |= check(pss.run_initialization, internal_state)
#     310 with SimpleTimer() as pass_time:
# --> 311     mutated |= check(pss.run_pass, internal_state)
#     312 with SimpleTimer() as finalize_time:
#     313     mutated |= check(pss.run_finalizer, internal_state)
#
# File c:\Users\Hiep\AppData\Local\Programs\Python\Python312\Lib\site-packages\numba\core\compiler_machinery.py:272, in PassManager._runPass.<locals>.check(func, compiler_state)
#     271 def check(func, compiler_state):
# --> 272     mangled = func(compiler_state)
#     273     if mangled not in (True, False):
#     274         msg = ("CompilerPass implementations should return True/False. "
#     275                "CompilerPass with name '%s' did not.")
#
# File c:\Users\Hiep\AppData\Local\Programs\Python\Python312\Lib\site-packages\numba\core\typed_passes.py:114, in BaseTypeInference.run_pass(self, state)
#     108 """
#     109 Type inference and legalization
#     110 """
#     111 with fallback_context(state, 'Function "%s" failed type inference'
#     112                       % (state.func_id.func_name,)):
#     113     # Type inference
# --> 114     typemap, return_type, calltypes, errs = type_inference_stage(
#     115         state.typingctx,
#     116         state.targetctx,
#     117         state.func_ir,
#     118         state.args,
#     119         state.return_type,
#     120         state.locals,
#     121         raise_errors=self._raise_errors)
#     122     state.typemap = typemap
#     123     # save errors in case of partial typing
#
# File c:\Users\Hiep\AppData\Local\Programs\Python\Python312\Lib\site-packages\numba\core\typed_passes.py:95, in type_inference_stage(typingctx, targetctx, interp, args, return_type, locals, raise_errors)
#      93     infer.build_constraint()
#      94     # return errors in case of partial typing
# ---> 95     errs = infer.propagate(raise_errors=raise_errors)
#      96     typemap, restype, calltypes = infer.unify(raise_errors=raise_errors)
#      98 return _TypingResults(typemap, restype, calltypes, errs)
#
# File c:\Users\Hiep\AppData\Local\Programs\Python\Python312\Lib\site-packages\numba\core\typeinfer.py:1075, in TypeInferer.propagate(self, raise_errors)
#    1072 oldtoken = newtoken
#    1073 # Errors can appear when the type set is incomplete; only
#    1074 # raise them when there is no progress anymore.
# -> 1075 errors = self.constraints.propagate(self)
#    1076 newtoken = self.get_state_token()
#    1077 self.debug.propagate_finished()
#
# File c:\Users\Hiep\AppData\Local\Programs\Python\Python312\Lib\site-packages\numba\core\typeinfer.py:160, in ConstraintNetwork.propagate(self, typeinfer)
#     157 with typeinfer.warnings.catch_warnings(filename=loc.filename,
#     158                                        lineno=loc.line):
#     159     try:
# --> 160         constraint(typeinfer)
#     161     except ForceLiteralArg as e:
#     162         errors.append(e)
#
# File c:\Users\Hiep\AppData\Local\Programs\Python\Python312\Lib\site-packages\numba\core\typeinfer.py:572, in CallConstraint.__call__(self, typeinfer)
#     569     fnty = typevars[self.func].getone()
#     570 with new_error_context("resolving callee type: {fnty}",
#     571                        fnty=fnty):
# --> 572     self.resolve(typeinfer, typevars, fnty)
#
# File c:\Users\Hiep\AppData\Local\Programs\Python\Python312\Lib\site-packages\numba\core\typeinfer.py:595, in CallConstraint.resolve(self, typeinfer, typevars, fnty)
#     593     fnty = fnty.instance_type
#     594 try:
# --> 595     sig = typeinfer.resolve_call(fnty, pos_args, kw_args)
#     596 except ForceLiteralArg as e:
#     597     # Adjust for bound methods
#     598     folding_args = ((fnty.this,) + tuple(self.args)
#     599                     if isinstance(fnty, types.BoundFunction)
#     600                     else self.args)
#
# File c:\Users\Hiep\AppData\Local\Programs\Python\Python312\Lib\site-packages\numba\core\typeinfer.py:1569, in TypeInferer.resolve_call(self, fnty, pos_args, kw_args)
#    1566     return sig
#    1567 else:
#    1568     # Normal non-recursive call
# -> 1569     return self.context.resolve_function_type(fnty, pos_args, kw_args)
#
# File c:\Users\Hiep\AppData\Local\Programs\Python\Python312\Lib\site-packages\numba\core\typing\context.py:279, in BaseContext.resolve_function_type(self, func, args, kws)
#     277 # Prefer user definition first
#     278 try:
# --> 279     res = self._resolve_user_function_type(func, args, kws)
#     280 except errors.TypingError as e:
#     281     # Capture any typing error
#     282     last_exception = e
#
# File c:\Users\Hiep\AppData\Local\Programs\Python\Python312\Lib\site-packages\numba\core\typing\context.py:335, in BaseContext._resolve_user_function_type(self, func, args, kws, literals)
#     331         return self.resolve_function_type(func_type, args, kws)
#     333 if isinstance(func, types.Callable):
#     334     # XXX fold this into the __call__ attribute logic?
# --> 335     return func.get_call_type(self, args, kws)
#
# File c:\Users\Hiep\AppData\Local\Programs\Python\Python312\Lib\site-packages\numba\core\types\functions.py:401, in BoundFunction.get_call_type(self, context, args, kws)
#     398 if uselit:
#     399     # Try with Literal
#     400     try:
# --> 401         out = template.apply(args, kws)
#     402     except Exception as exc:
#     403         if not isinstance(exc, errors.NumbaError):
#
# File c:\Users\Hiep\AppData\Local\Programs\Python\Python312\Lib\site-packages\numba\core\typing\templates.py:358, in AbstractTemplate.apply(self, args, kws)
#     356 def apply(self, args, kws):
#     357     generic = getattr(self, "generic")
# --> 358     sig = generic(args, kws)
#     359     # Enforce that *generic()* must return None or Signature
#     360     if sig is not None:
#
# File c:\Users\Hiep\AppData\Local\Programs\Python\Python312\Lib\site-packages\numba\experimental\jitclass\base.py:429, in ClassAttribute.generic_resolve.<locals>.MethodTemplate.generic(self, args, kws)
#     427 def generic(self, args, kws):
#     428     args = (instance,) + tuple(args)
# --> 429     sig = disp_type.get_call_type(self.context, args, kws)
#     430     return sig.as_method()
#
# File c:\Users\Hiep\AppData\Local\Programs\Python\Python312\Lib\site-packages\numba\core\types\functions.py:541, in Dispatcher.get_call_type(self, context, args, kws)
#     534 def get_call_type(self, context, args, kws):
#     535     """
#     536     Resolve a call to this dispatcher using the given argument types.
#     537     A signature returned and it is ensured that a compiled specialization
#     538     is available for it.
#     539     """
#     540     template, pysig, args, kws = \
# --> 541         self.dispatcher.get_call_template(args, kws)
#     542     sig = template(context).apply(args, kws)
#     543     if sig:
#
# File c:\Users\Hiep\AppData\Local\Programs\Python\Python312\Lib\site-packages\numba\core\dispatcher.py:319, in _DispatcherBase.get_call_template(self, args, kws)
#     317 # Ensure an overload is available
#     318 if self._can_compile:
# --> 319     self.compile(tuple(args))
#     321 # Create function type for typing
#     322 func_name = self.py_func.__name__
#
# File c:\Users\Hiep\AppData\Local\Programs\Python\Python312\Lib\site-packages\numba\core\dispatcher.py:908, in Dispatcher.compile(self, sig)
#     906 with ev.trigger_event("numba:compile", data=ev_details):
#     907     try:
# --> 908         cres = self._compiler.compile(args, return_type)
#     909     except errors.ForceLiteralArg as e:
#     910         def folded(args, kws):
#
# File c:\Users\Hiep\AppData\Local\Programs\Python\Python312\Lib\site-packages\numba\core\dispatcher.py:80, in _FunctionCompiler.compile(self, args, return_type)
#      79 def compile(self, args, return_type):
# ---> 80     status, retval = self._compile_cached(args, return_type)
#      81     if status:
#      82         return retval
#
# File c:\Users\Hiep\AppData\Local\Programs\Python\Python312\Lib\site-packages\numba\core\dispatcher.py:94, in _FunctionCompiler._compile_cached(self, args, return_type)
#      91     pass
#      93 try:
# ---> 94     retval = self._compile_core(args, return_type)
#      95 except errors.TypingError as e:
#      96     self._failed_cache[key] = e
#
# File c:\Users\Hiep\AppData\Local\Programs\Python\Python312\Lib\site-packages\numba\core\dispatcher.py:107, in _FunctionCompiler._compile_core(self, args, return_type)
#     104 flags = self._customize_flags(flags)
#     106 impl = self._get_implementation(args, {})
# --> 107 cres = compiler.compile_extra(self.targetdescr.typing_context,
#     108                               self.targetdescr.target_context,
#     109                               impl,
#     110                               args=args, return_type=return_type,
#     111                               flags=flags, locals=self.locals,
#     112                               pipeline_class=self.pipeline_class)
#     113 # Check typing error if object mode is used
#     114 if cres.typing_error is not None and not flags.enable_pyobject:
#
# File c:\Users\Hiep\AppData\Local\Programs\Python\Python312\Lib\site-packages\numba\core\compiler.py:739, in compile_extra(typingctx, targetctx, func, args, return_type, flags, locals, library, pipeline_class)
#     715 """Compiler entry point
#     716
#     717 Parameter
#    (...)    735     compiler pipeline
#     736 """
#     737 pipeline = pipeline_class(typingctx, targetctx, library,
#     738                           args, return_type, flags, locals)
# --> 739 return pipeline.compile_extra(func)
#
# File c:\Users\Hiep\AppData\Local\Programs\Python\Python312\Lib\site-packages\numba\core\compiler.py:439, in CompilerBase.compile_extra(self, func)
#     437 self.state.lifted = ()
#     438 self.state.lifted_from = None
# --> 439 return self._compile_bytecode()
#
# File c:\Users\Hiep\AppData\Local\Programs\Python\Python312\Lib\site-packages\numba\core\compiler.py:505, in CompilerBase._compile_bytecode(self)
#     501 """
#     502 Populate and run pipeline for bytecode input
#     503 """
#     504 assert self.state.func_ir is None
# --> 505 return self._compile_core()
#
# File c:\Users\Hiep\AppData\Local\Programs\Python\Python312\Lib\site-packages\numba\core\compiler.py:473, in CompilerBase._compile_core(self)
#     471 res = None
#     472 try:
# --> 473     pm.run(self.state)
#     474     if self.state.cr is not None:
#     475         break
#
# File c:\Users\Hiep\AppData\Local\Programs\Python\Python312\Lib\site-packages\numba\core\compiler_machinery.py:356, in PassManager.run(self, state)
#     354 pass_inst = _pass_registry.get(pss).pass_inst
#     355 if isinstance(pass_inst, CompilerPass):
# --> 356     self._runPass(idx, pass_inst, state)
#     357 else:
#     358     raise BaseException("Legacy pass in use")
#
# File c:\Users\Hiep\AppData\Local\Programs\Python\Python312\Lib\site-packages\numba\core\compiler_lock.py:35, in _CompilerLock.__call__.<locals>._acquire_compile_lock(*args, **kwargs)
#      32 @functools.wraps(func)
#      33 def _acquire_compile_lock(*args, **kwargs):
#      34     with self:
# ---> 35         return func(*args, **kwargs)
#
# File c:\Users\Hiep\AppData\Local\Programs\Python\Python312\Lib\site-packages\numba\core\compiler_machinery.py:311, in PassManager._runPass(self, index, pss, internal_state)
#     309     mutated |= check(pss.run_initialization, internal_state)
#     310 with SimpleTimer() as pass_time:
# --> 311     mutated |= check(pss.run_pass, internal_state)
#     312 with SimpleTimer() as finalize_time:
#     313     mutated |= check(pss.run_finalizer, internal_state)
#
# File c:\Users\Hiep\AppData\Local\Programs\Python\Python312\Lib\site-packages\numba\core\compiler_machinery.py:272, in PassManager._runPass.<locals>.check(func, compiler_state)
#     271 def check(func, compiler_state):
# --> 272     mangled = func(compiler_state)
#     273     if mangled not in (True, False):
#     274         msg = ("CompilerPass implementations should return True/False. "
#     275                "CompilerPass with name '%s' did not.")
#
# File c:\Users\Hiep\AppData\Local\Programs\Python\Python312\Lib\site-packages\numba\core\typed_passes.py:472, in BaseNativeLowering.run_pass(self, state)
#     469 with targetctx.push_code_library(library):
#     470     lower = self.lowering_class(targetctx, library, fndesc, interp,
#     471                                 metadata=metadata)
# --> 472     lower.lower()
#     473     if not flags.no_cpython_wrapper:
#     474         lower.create_cpython_wrapper(flags.release_gil)
#
# File c:\Users\Hiep\AppData\Local\Programs\Python\Python312\Lib\site-packages\numba\core\lowering.py:216, in BaseLower.lower(self)
#     213 self.context.post_lowering(self.module, self.library)
#     215 # Materialize LLVM Module
# --> 216 self.library.add_ir_module(self.module)
#
# File c:\Users\Hiep\AppData\Local\Programs\Python\Python312\Lib\site-packages\numba\core\codegen.py:739, in CPUCodeLibrary.add_ir_module(self, ir_module)
#     737 ll_module.name = ir_module.name
#     738 ll_module.verify()
# --> 739 self.add_llvm_module(ll_module)
#
# File c:\Users\Hiep\AppData\Local\Programs\Python\Python312\Lib\site-packages\numba\core\codegen.py:742, in CPUCodeLibrary.add_llvm_module(self, ll_module)
#     741 def add_llvm_module(self, ll_module):
# --> 742     self._optimize_functions(ll_module)
#     743     # TODO: we shouldn't need to recreate the LLVM module object
#     744     if not config.LLVM_REFPRUNE_PASS:
#
# File c:\Users\Hiep\AppData\Local\Programs\Python\Python312\Lib\site-packages\numba\core\codegen.py:665, in CPUCodeLibrary._optimize_functions(self, ll_module)
#     663 k = f"Function passes on {func.name!r}"
#     664 with self._recorded_timings.record(k, pb):
# --> 665     fpm.run(func, pb)
#
# File c:\Users\Hiep\AppData\Local\Programs\Python\Python312\Lib\site-packages\llvmlite\binding\newpassmanagers.py:124, in NewPassManager.run(self, IR, pb)
#     122     ffi.lib.LLVMPY_RunNewModulePassManager(self, IR, pb)
#     123 else:
# --> 124     ffi.lib.LLVMPY_RunNewFunctionPassManager(self, IR, pb)
#
# File c:\Users\Hiep\AppData\Local\Programs\Python\Python312\Lib\site-packages\llvmlite\binding\ffi.py:212, in _lib_fn_wrapper.__call__(self, *args, **kwargs)
#     210 def __call__(self, *args, **kwargs):
#     211     with self._lock:
# --> 212         return self._cfn(*args, **kwargs)
#
# KeyboardInterrupt:

# %%
print("=== TPR Experiment Summary ===")
for current_nT in nT_list:
    filepath = get_save_path(p, nS, current_nT, K, lambda_sel, lambda0)
    j_values, pvals = load_progress(filepath)
    
    if not pvals:
        print(f"nT={current_nT}: No data found.")
        continue
    
    pvals_arr = np.asarray(pvals)
    # Tính TPR: tỉ lệ số lần p-value <= alpha
    rejection_rate = (pvals_arr <= alpha).mean()
    print(f"nT={current_nT}: {len(pvals)} valid runs | Empirical TPR @ alpha={alpha}: {rejection_rate:.3f}")
# Out:
# === TPR Experiment Summary ===
# nT=50: 994 valid runs | Empirical TPR @ alpha=0.05: 0.279
# nT=75: 998 valid runs | Empirical TPR @ alpha=0.05: 0.428
# nT=100: 309 valid runs | Empirical TPR @ alpha=0.05: 0.521

# %%
print("=== TPR Experiment Summary ===")
for current_nT in nT_list:
    filepath = get_save_path(p, nS, current_nT, K, lambda_sel, lambda0)
    j_values, pvals = load_progress(filepath)
    
    if not pvals:
        print(f"nT={current_nT}: No data found.")
        continue
    
    j_arr = np.asarray(j_values)
    pvals_arr = np.asarray(pvals)
    
    # Tính TPR: tỉ lệ số lần p-value <= alpha CHỈ trên các features thực sự (j < 5)
    mask = j_arr < 5
    if mask.sum() > 0:
        rejection_rate = (pvals_arr[mask] <= alpha).mean()
        print(f"nT={current_nT}: {len(pvals)} valid runs | {mask.sum()} true signal runs | Empirical TPR @ alpha={alpha}: {rejection_rate:.3f}")
    else:
        print(f"nT={current_nT}: {len(pvals)} valid runs | 0 true signal runs | Empirical TPR @ alpha={alpha}: N/A")
# Out:
# === TPR Experiment Summary ===
# nT=50: 994 valid runs | 841 true signal runs | Empirical TPR @ alpha=0.05: 0.321
# nT=75: 998 valid runs | 909 true signal runs | Empirical TPR @ alpha=0.05: 0.468
# nT=100: 309 valid runs | 290 true signal runs | Empirical TPR @ alpha=0.05: 0.552
