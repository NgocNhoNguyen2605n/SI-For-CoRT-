# %%
from pathlib import Path
import random
import sys

import matplotlib.pyplot as plt
import numpy as np
from scipy import stats

cwd = Path.cwd().resolve()
candidates = [cwd, cwd.parent]
REPO_ROOT = next((candidate for candidate in candidates if (candidate / "cort_si").exists()), None)
if REPO_ROOT is None:
    raise RuntimeError("Could not locate the repo root containing the cort_si package.")
if str(REPO_ROOT) not in sys.path:
    sys.path.insert(0, str(REPO_ROOT))

from cort_si import (
    adaptive_source_selection,
    construct_Y,
    construct_Sigma,
    construct_folds,
    construct_test_statistic,
    gen_data,
    solve_cort_model,
)

RESULTS_DIR = REPO_ROOT / "run_experiment" / "results"
RESULTS_DIR.mkdir(parents=True, exist_ok=True)

# %%
p = 300
nS = 120
num_info_aux = 3
num_uninfo_aux = 2
K = num_info_aux + num_uninfo_aux
lambda_sel = 0.6
lambda0 = 0.7
T = 5
nT_list = [50, 75, 100]

num_runs = 1000
base_seed = 40000
alpha = 0.05
true_beta_scale = 0.0
rho = 0.0
sigma_noise = 1.0
source_shift_sd = 0.3
covariate_shift = False
save_interval = 1
verbose=False

print(f"num_runs = {num_runs}")
print(f"fixed alpha = {alpha}")
print(f"Null model true_beta scale = {true_beta_scale}")
print(f"K = {K}, p = {p}, nS = {nS}")
print(f"Testing nT values: {nT_list}")
# Out:
# num_runs = 1000
# fixed alpha = 0.05
# Null model true_beta scale = 0.0
# K = 5, p = 300, nS = 120
# Testing nT values: [50, 75, 100]

# %%
def get_save_path(p_val, nS_val, nT_val, K, lambda_sel, lambda0):
    return RESULTS_DIR / f"DS_fpr_p{p_val}_nS{nS_val}_nT{nT_val}_K{K}_lamsel{lambda_sel}_lam0{lambda0}.npz"


def load_progress(filepath):
    if filepath.exists():
        data = np.load(filepath)
        # Hỗ trợ cả file cũ (chỉ có null_pvalues) và file mới (có thêm j_values)
        if 'j_values' in data and 'null_pvalues' in data:
            return list(data['j_values']), list(data['null_pvalues'])
        elif 'null_pvalues' in data:
            return [], list(data['null_pvalues'])
    return [], []

def save_progress(filepath, j_values, null_pvalues, p_val, nS_val, nT_val, num_runs_val, alpha_val):
    np.savez(
        filepath,
        j_values=np.asarray(j_values, dtype=int),
        null_pvalues=np.asarray(null_pvalues, dtype=float),
        p=np.asarray([p_val], dtype=int),
        nS=np.asarray([nS_val], dtype=int),
        nT=np.asarray([nT_val], dtype=int),
        num_runs=np.asarray([num_runs_val], dtype=int),
        alpha=np.asarray([alpha_val], dtype=float),
    )

# %%
def generate_null_instance(nT_val, iteration_seed):
    return gen_data.generate_data(
        p=p,
        nS=nS,
        nT=nT_val,
        K=K,
        true_beta=true_beta_scale,
        rho=rho,
        sigma_noise=sigma_noise,
        source_shift_sd=source_shift_sd,
        covariate_shift=covariate_shift,
        seed=iteration_seed,
        num_info_aux=num_info_aux,
        num_uninfo_aux= num_uninfo_aux
    )


def split_indices_in_half(num_rows, rng):
    shuffled = rng.permutation(num_rows)
    selection_idx, inference_idx = [np.sort(block.astype(int)) for block in np.array_split(shuffled, 2)]
    if selection_idx.size == 0 or inference_idx.size == 0:
        return None, None
    return selection_idx, inference_idx


def split_dataset_block(X, Y, Sigma, rng):
    selection_idx, inference_idx = split_indices_in_half(X.shape[0], rng)
    if selection_idx is None:
        return None

    Sigma = np.asarray(Sigma)
    return {
        "X_selection": X[selection_idx],
        "Y_selection": np.asarray(Y)[selection_idx],
        "Sigma_selection": Sigma[np.ix_(selection_idx, selection_idx)],
        "X_inference": X[inference_idx],
        "Y_inference": np.asarray(Y)[inference_idx],
        "Sigma_inference": Sigma[np.ix_(inference_idx, inference_idx)],
    }


def split_instance_for_datasplit(XS_list, YS_list, SigmaS_list, X0, Y0, Sigma0, split_seed):
    rng = np.random.default_rng(split_seed)

    target_split = split_dataset_block(X0, Y0, Sigma0, rng)
    if target_split is None:
        return None

    return {
        "XS_selection_list": XS_list,
        "YS_selection_list": YS_list,
        "SigmaS_selection_list": SigmaS_list,
        "X0_selection": target_split["X_selection"],
        "Y0_selection": target_split["Y_selection"],
        "Sigma0_selection": target_split["Sigma_selection"],
        "XS_inference_list": XS_list,
        "YS_inference_list": YS_list,
        "SigmaS_inference_list": SigmaS_list,
        "X0_inference": target_split["X_inference"],
        "Y0_inference": target_split["Y_inference"],
        "Sigma0_inference": target_split["Sigma_inference"],
    }


def compute_random_selected_datasplit_pvalue(X0, Y0, XS_list, YS_list, SigmaS_list, Sigma0, lambdak_list, split_seed, feature_seed):
    split_data = split_instance_for_datasplit(XS_list, YS_list, SigmaS_list, X0, Y0, Sigma0, split_seed)
    if split_data is None:
        return None

    folds = construct_folds(split_data["X0_selection"].shape[0], T=T, shuffle=False)
    I_obs = adaptive_source_selection(
        split_data["X0_selection"],
        split_data["Y0_selection"],
        split_data["XS_selection_list"],
        split_data["YS_selection_list"],
        folds,
        lambda_sel,
        verbose=verbose,
    )
    _, beta0_hat, _, _ = solve_cort_model(
        split_data["X0_selection"],
        split_data["Y0_selection"],
        split_data["XS_selection_list"],
        split_data["YS_selection_list"],
        I_obs,
        lambda0,
        lambdak_list,
        verbose=verbose,
        label="Observed CoRT fit on selection half",
    )
    M_obs = [idx for idx, value in enumerate(beta0_hat) if value != 0]
    if not M_obs:
        return None

    feature_idx = random.Random(feature_seed).choice(M_obs)
    Y_inference = construct_Y(split_data["YS_inference_list"], split_data["Y0_inference"])
    Sigma_inference = construct_Sigma(split_data["SigmaS_inference_list"], split_data["Sigma0_inference"])
    X0M_inference = split_data["X0_inference"][:, M_obs]
    etaj, etajTy = construct_test_statistic(
        feature_idx,
        X0M_inference,
        Y_inference,
        M_obs,
        split_data["Y0_inference"].shape[0],
        Y_inference.shape[0],
    )

    variance = float(np.asarray(etaj.T @ Sigma_inference @ etaj).item())
    if not np.isfinite(variance) or variance <= 0.0:
        return None

    z_score = float(etajTy / np.sqrt(variance))
    datasplit_pvalue = float(2.0 * stats.norm.sf(abs(z_score)))

    return int(feature_idx), datasplit_pvalue

# %%
def run_resumable_fpr_experiment(nT_val, total_runs, seed_base, save_intvl=10):
    filepath = get_save_path(p, nS, nT_val, K, lambda_sel, lambda0)
    j_values, null_pvalues = load_progress(filepath)
    start_iteration = len(null_pvalues)

    if start_iteration >= total_runs:
        print(f"Experiment for nT={nT_val} already completed ({total_runs} runs).")
        return j_values, null_pvalues

    print(f"Starting/Resuming experiment for nT={nT_val} from run {start_iteration}/{total_runs}...")

    cnt = 0
    sum = 0
    mau = 0
    for iteration in range(start_iteration, total_runs):
        data_seed = base_seed + iteration
        XS_list, YS_list, X0, Y0, _, SigmaS_list, Sigma0, _ = generate_null_instance(nT_val, data_seed)
        lambdak_list = [lambda0] * len(XS_list)
        result = compute_random_selected_datasplit_pvalue(
            X0,
            Y0,
            XS_list,
            YS_list,
            SigmaS_list,
            Sigma0,
            lambdak_list,
            split_seed=data_seed + 10000,
            feature_seed=data_seed + 20000,
        )

        if result is not None:
            j_val, p_sel = result
            if p_sel is not None and np.isfinite(p_sel):
                if p_sel <= alpha:
                    cnt += 1
                sum += 1
            mau += 1
            j_values.append(int(j_val))
            null_pvalues.append(float(p_sel))

        if (iteration + 1) % save_intvl == 0 or (iteration + 1) == total_runs:
            save_progress(filepath, j_values, null_pvalues, p, nS, nT_val, total_runs, alpha)
            print(f"  [nT={nT_val}] Saved progress: {iteration + 1}/{total_runs} runs completed.")
            if sum > 0:
                print(f"Empirical FPR @ alpha={alpha}: {(cnt / sum):.3f} | total run : {sum} | cnt: {cnt} | not signal: {mau - sum}")

    return j_values, null_pvalues

# %%
for current_nT in nT_list:
    run_resumable_fpr_experiment(current_nT, num_runs, base_seed, save_intvl=save_interval)
# Out:
# Experiment for nT=50 already completed (1000 runs).
# Starting/Resuming experiment for nT=75 from run 955/1000...
#   [nT=75] Saved progress: 956/1000 runs completed.
# Empirical FPR @ alpha=0.05: 0.000 | total run : 1 | cnt: 0 | not signal: 0
#   [nT=75] Saved progress: 957/1000 runs completed.
# Empirical FPR @ alpha=0.05: 0.000 | total run : 1 | cnt: 0 | not signal: 0
#   [nT=75] Saved progress: 958/1000 runs completed.
# Empirical FPR @ alpha=0.05: 0.000 | total run : 2 | cnt: 0 | not signal: 0
#   [nT=75] Saved progress: 959/1000 runs completed.
# Empirical FPR @ alpha=0.05: 0.000 | total run : 3 | cnt: 0 | not signal: 0
#   [nT=75] Saved progress: 960/1000 runs completed.
# Empirical FPR @ alpha=0.05: 0.000 | total run : 4 | cnt: 0 | not signal: 0
#   [nT=75] Saved progress: 961/1000 runs completed.
# Empirical FPR @ alpha=0.05: 0.000 | total run : 5 | cnt: 0 | not signal: 0
#   [nT=75] Saved progress: 962/1000 runs completed.
# Empirical FPR @ alpha=0.05: 0.000 | total run : 6 | cnt: 0 | not signal: 0
#   [nT=75] Saved progress: 963/1000 runs completed.
# Empirical FPR @ alpha=0.05: 0.000 | total run : 6 | cnt: 0 | not signal: 0
#   [nT=75] Saved progress: 964/1000 runs completed.
# Empirical FPR @ alpha=0.05: 0.000 | total run : 6 | cnt: 0 | not signal: 0
#   [nT=75] Saved progress: 965/1000 runs completed.
# Empirical FPR @ alpha=0.05: 0.000 | total run : 7 | cnt: 0 | not signal: 0
#   [nT=75] Saved progress: 966/1000 runs completed.
# Empirical FPR @ alpha=0.05: 0.000 | total run : 8 | cnt: 0 | not signal: 0
#   [nT=75] Saved progress: 967/1000 runs completed.
# Empirical FPR @ alpha=0.05: 0.000 | total run : 8 | cnt: 0 | not signal: 0
#   [nT=75] Saved progress: 968/1000 runs completed.
# Empirical FPR @ alpha=0.05: 0.000 | total run : 9 | cnt: 0 | not signal: 0
#   [nT=75] Saved progress: 969/1000 runs completed.
# Empirical FPR @ alpha=0.05: 0.100 | total run : 10 | cnt: 1 | not signal: 0
#   [nT=75] Saved progress: 970/1000 runs completed.
# Empirical FPR @ alpha=0.05: 0.091 | total run : 11 | cnt: 1 | not signal: 0
#   [nT=75] Saved progress: 971/1000 runs completed.
# Empirical FPR @ alpha=0.05: 0.091 | total run : 11 | cnt: 1 | not signal: 0
#   [nT=75] Saved progress: 972/1000 runs completed.
# Empirical FPR @ alpha=0.05: 0.091 | total run : 11 | cnt: 1 | not signal: 0
#   [nT=75] Saved progress: 973/1000 runs completed.
# Empirical FPR @ alpha=0.05: 0.083 | total run : 12 | cnt: 1 | not signal: 0
#   [nT=75] Saved progress: 974/1000 runs completed.
# Empirical FPR @ alpha=0.05: 0.083 | total run : 12 | cnt: 1 | not signal: 0
#   [nT=75] Saved progress: 975/1000 runs completed.
# Empirical FPR @ alpha=0.05: 0.077 | total run : 13 | cnt: 1 | not signal: 0
#   [nT=75] Saved progress: 976/1000 runs completed.
# Empirical FPR @ alpha=0.05: 0.071 | total run : 14 | cnt: 1 | not signal: 0
#   [nT=75] Saved progress: 977/1000 runs completed.
# Empirical FPR @ alpha=0.05: 0.067 | total run : 15 | cnt: 1 | not signal: 0
#   [nT=75] Saved progress: 978/1000 runs completed.
# Empirical FPR @ alpha=0.05: 0.062 | total run : 16 | cnt: 1 | not signal: 0
#   [nT=75] Saved progress: 979/1000 runs completed.
# Empirical FPR @ alpha=0.05: 0.062 | total run : 16 | cnt: 1 | not signal: 0
#   [nT=75] Saved progress: 980/1000 runs completed.
# Empirical FPR @ alpha=0.05: 0.059 | total run : 17 | cnt: 1 | not signal: 0
#   [nT=75] Saved progress: 981/1000 runs completed.
# Empirical FPR @ alpha=0.05: 0.056 | total run : 18 | cnt: 1 | not signal: 0
#   [nT=75] Saved progress: 982/1000 runs completed.
# Empirical FPR @ alpha=0.05: 0.056 | total run : 18 | cnt: 1 | not signal: 0
#   [nT=75] Saved progress: 983/1000 runs completed.
# Empirical FPR @ alpha=0.05: 0.053 | total run : 19 | cnt: 1 | not signal: 0
#   [nT=75] Saved progress: 984/1000 runs completed.
# Empirical FPR @ alpha=0.05: 0.053 | total run : 19 | cnt: 1 | not signal: 0
#   [nT=75] Saved progress: 985/1000 runs completed.
# Empirical FPR @ alpha=0.05: 0.050 | total run : 20 | cnt: 1 | not signal: 0
#   [nT=75] Saved progress: 986/1000 runs completed.
# Empirical FPR @ alpha=0.05: 0.050 | total run : 20 | cnt: 1 | not signal: 0
#   [nT=75] Saved progress: 987/1000 runs completed.
# Empirical FPR @ alpha=0.05: 0.050 | total run : 20 | cnt: 1 | not signal: 0
#   [nT=75] Saved progress: 988/1000 runs completed.
# Empirical FPR @ alpha=0.05: 0.048 | total run : 21 | cnt: 1 | not signal: 0
#   [nT=75] Saved progress: 989/1000 runs completed.
# Empirical FPR @ alpha=0.05: 0.045 | total run : 22 | cnt: 1 | not signal: 0
#   [nT=75] Saved progress: 990/1000 runs completed.
# Empirical FPR @ alpha=0.05: 0.045 | total run : 22 | cnt: 1 | not signal: 0
#   [nT=75] Saved progress: 991/1000 runs completed.
# Empirical FPR @ alpha=0.05: 0.045 | total run : 22 | cnt: 1 | not signal: 0
#   [nT=75] Saved progress: 992/1000 runs completed.
# Empirical FPR @ alpha=0.05: 0.043 | total run : 23 | cnt: 1 | not signal: 0
#   [nT=75] Saved progress: 993/1000 runs completed.
# Empirical FPR @ alpha=0.05: 0.043 | total run : 23 | cnt: 1 | not signal: 0
#   [nT=75] Saved progress: 994/1000 runs completed.
# Empirical FPR @ alpha=0.05: 0.042 | total run : 24 | cnt: 1 | not signal: 0
#   [nT=75] Saved progress: 995/1000 runs completed.
# Empirical FPR @ alpha=0.05: 0.080 | total run : 25 | cnt: 2 | not signal: 0
#   [nT=75] Saved progress: 996/1000 runs completed.
# Empirical FPR @ alpha=0.05: 0.080 | total run : 25 | cnt: 2 | not signal: 0
#   [nT=75] Saved progress: 997/1000 runs completed.
# Empirical FPR @ alpha=0.05: 0.077 | total run : 26 | cnt: 2 | not signal: 0
#   [nT=75] Saved progress: 998/1000 runs completed.
# Empirical FPR @ alpha=0.05: 0.077 | total run : 26 | cnt: 2 | not signal: 0
#   [nT=75] Saved progress: 999/1000 runs completed.
# Empirical FPR @ alpha=0.05: 0.077 | total run : 26 | cnt: 2 | not signal: 0
#   [nT=75] Saved progress: 1000/1000 runs completed.
# Empirical FPR @ alpha=0.05: 0.077 | total run : 26 | cnt: 2 | not signal: 0
# Starting/Resuming experiment for nT=100 from run 224/1000...
#   [nT=100] Saved progress: 225/1000 runs completed.
#   [nT=100] Saved progress: 226/1000 runs completed.
#   [nT=100] Saved progress: 227/1000 runs completed.
# Empirical FPR @ alpha=0.05: 0.000 | total run : 1 | cnt: 0 | not signal: 0
#   [nT=100] Saved progress: 228/1000 runs completed.
# Empirical FPR @ alpha=0.05: 0.000 | total run : 2 | cnt: 0 | not signal: 0
#   [nT=100] Saved progress: 229/1000 runs completed.
# Empirical FPR @ alpha=0.05: 0.000 | total run : 3 | cnt: 0 | not signal: 0
#   [nT=100] Saved progress: 230/1000 runs completed.
# Empirical FPR @ alpha=0.05: 0.000 | total run : 3 | cnt: 0 | not signal: 0
#   [nT=100] Saved progress: 231/1000 runs completed.
# Empirical FPR @ alpha=0.05: 0.000 | total run : 3 | cnt: 0 | not signal: 0
#   [nT=100] Saved progress: 232/1000 runs completed.
# Empirical FPR @ alpha=0.05: 0.000 | total run : 3 | cnt: 0 | not signal: 0
#   [nT=100] Saved progress: 233/1000 runs completed.
# Empirical FPR @ alpha=0.05: 0.000 | total run : 3 | cnt: 0 | not signal: 0
#   [nT=100] Saved progress: 234/1000 runs completed.
# Empirical FPR @ alpha=0.05: 0.000 | total run : 4 | cnt: 0 | not signal: 0
#   [nT=100] Saved progress: 235/1000 runs completed.
# Empirical FPR @ alpha=0.05: 0.000 | total run : 4 | cnt: 0 | not signal: 0
#   [nT=100] Saved progress: 236/1000 runs completed.
# Empirical FPR @ alpha=0.05: 0.000 | total run : 5 | cnt: 0 | not signal: 0
#   [nT=100] Saved progress: 237/1000 runs completed.
# Empirical FPR @ alpha=0.05: 0.000 | total run : 5 | cnt: 0 | not signal: 0
#   [nT=100] Saved progress: 238/1000 runs completed.
# Empirical FPR @ alpha=0.05: 0.000 | total run : 6 | cnt: 0 | not signal: 0
#   [nT=100] Saved progress: 239/1000 runs completed.
# Empirical FPR @ alpha=0.05: 0.000 | total run : 7 | cnt: 0 | not signal: 0
#   [nT=100] Saved progress: 240/1000 runs completed.
# Empirical FPR @ alpha=0.05: 0.000 | total run : 8 | cnt: 0 | not signal: 0
#   [nT=100] Saved progress: 241/1000 runs completed.
# Empirical FPR @ alpha=0.05: 0.000 | total run : 8 | cnt: 0 | not signal: 0
#   [nT=100] Saved progress: 242/1000 runs completed.
# Empirical FPR @ alpha=0.05: 0.000 | total run : 9 | cnt: 0 | not signal: 0
#   [nT=100] Saved progress:
1000 runs completed.
# Empirical FPR @ alpha=0.05: 0.043 | total run : 400 | cnt: 17 | not signal: 0
#   [nT=100] Saved progress: 882/1000 runs completed.
# Empirical FPR @ alpha=0.05: 0.043 | total run : 400 | cnt: 17 | not signal: 0
#   [nT=100] Saved progress: 883/1000 runs completed.
# Empirical FPR @ alpha=0.05: 0.043 | total run : 400 | cnt: 17 | not signal: 0
#   [nT=100] Saved progress: 884/1000 runs completed.
# Empirical FPR @ alpha=0.05: 0.042 | total run : 401 | cnt: 17 | not signal: 0
#   [nT=100] Saved progress: 885/1000 runs completed.
# Empirical FPR @ alpha=0.05: 0.042 | total run : 402 | cnt: 17 | not signal: 0
#   [nT=100] Saved progress: 886/1000 runs completed.
# Empirical FPR @ alpha=0.05: 0.042 | total run : 403 | cnt: 17 | not signal: 0
#   [nT=100] Saved progress: 887/1000 runs completed.
# Empirical FPR @ alpha=0.05: 0.042 | total run : 404 | cnt: 17 | not signal: 0
#   [nT=100] Saved progress: 888/1000 runs completed.
# Empirical FPR @ alpha=0.05: 0.042 | total run : 405 | cnt: 17 | not signal: 0
#   [nT=100] Saved progress: 889/1000 runs completed.
# Empirical FPR @ alpha=0.05: 0.042 | total run : 405 | cnt: 17 | not signal: 0
#   [nT=100] Saved progress: 890/1000 runs completed.
# Empirical FPR @ alpha=0.05: 0.042 | total run : 406 | cnt: 17 | not signal: 0
#   [nT=100] Saved progress: 891/1000 runs completed.
# Empirical FPR @ alpha=0.05: 0.042 | total run : 407 | cnt: 17 | not signal: 0
#   [nT=100] Saved progress: 892/1000 runs completed.
# Empirical FPR @ alpha=0.05: 0.042 | total run : 408 | cnt: 17 | not signal: 0
#   [nT=100] Saved progress: 893/1000 runs completed.
# Empirical FPR @ alpha=0.05: 0.042 | total run : 408 | cnt: 17 | not signal: 0
#   [nT=100] Saved progress: 894/1000 runs completed.
# Empirical FPR @ alpha=0.05: 0.042 | total run : 408 | cnt: 17 | not signal: 0
#   [nT=100] Saved progress: 895/1000 runs completed.
# Empirical FPR @ alpha=0.05: 0.042 | total run : 409 | cnt: 17 | not signal: 0
#   [nT=100] Saved progress: 896/1000 runs completed.
# Empirical FPR @ alpha=0.05: 0.044 | total run : 410 | cnt: 18 | not signal: 0
#   [nT=100] Saved progress: 897/1000 runs completed.
# Empirical FPR @ alpha=0.05: 0.044 | total run : 410 | cnt: 18 | not signal: 0
#   [nT=100] Saved progress: 898/1000 runs completed.
# Empirical FPR @ alpha=0.05: 0.044 | total run : 411 | cnt: 18 | not signal: 0
#   [nT=100] Saved progress: 899/1000 runs completed.
# Empirical FPR @ alpha=0.05: 0.044 | total run : 411 | cnt: 18 | not signal: 0
#   [nT=100] Saved progress: 900/1000 runs completed.
# Empirical FPR @ alpha=0.05: 0.044 | total run : 412 | cnt: 18 | not signal: 0
#   [nT=100] Saved progress: 901/1000 runs completed.
# Empirical FPR @ alpha=0.05: 0.044 | total run : 413 | cnt: 18 | not signal: 0
#   [nT=100] Saved progress: 902/1000 runs completed.
# Empirical FPR @ alpha=0.05: 0.043 | total run : 414 | cnt: 18 | not signal: 0
#   [nT=100] Saved progress: 903/1000 runs completed.
# Empirical FPR @ alpha=0.05: 0.043 | total run : 414 | cnt: 18 | not signal: 0
#   [nT=100] Saved progress: 904/1000 runs completed.
# Empirical FPR @ alpha=0.05: 0.043 | total run : 414 | cnt: 18 | not signal: 0
#   [nT=100] Saved progress: 905/1000 runs completed.
# Empirical FPR @ alpha=0.05: 0.043 | total run : 414 | cnt: 18 | not signal: 0
#   [nT=100] Saved progress: 906/1000 runs completed.
# Empirical FPR @ alpha=0.05: 0.043 | total run : 415 | cnt: 18 | not signal: 0
#   [nT=100] Saved progress: 907/1000 runs completed.
# Empirical FPR @ alpha=0.05: 0.043 | total run : 416 | cnt: 18 | not signal: 0
#   [nT=100] Saved progress: 908/1000 runs completed.
# Empirical FPR @ alpha=0.05: 0.043 | total run : 416 | cnt: 18 | not signal: 0
#   [nT=100] Saved progress: 909/1000 runs completed.
# Empirical FPR @ alpha=0.05: 0.043 | total run : 416 | cnt: 18 | not signal: 0
#   [nT=100] Saved progress: 910/1000 runs completed.
# Empirical FPR @ alpha=0.05: 0.043 | total run : 417 | cnt: 18 | not signal: 0
#   [nT=100] Saved progress: 911/1000 runs completed.
# Empirical FPR @ alpha=0.05: 0.043 | total run : 418 | cnt: 18 | not signal: 0
#   [nT=100] Saved progress: 912/1000 runs completed.
# Empirical FPR @ alpha=0.05: 0.045 | total run : 419 | cnt: 19 | not signal: 0
#   [nT=100] Saved progress: 913/1000 runs completed.
# Empirical FPR @ alpha=0.05: 0.045 | total run : 420 | cnt: 19 | not signal: 0
#   [nT=100] Saved progress: 914/1000 runs completed.
# Empirical FPR @ alpha=0.05: 0.045 | total run : 420 | cnt: 19 | not signal: 0
#   [nT=100] Saved progress: 915/1000 runs completed.
# Empirical FPR @ alpha=0.05: 0.045 | total run : 421 | cnt: 19 | not signal: 0
#   [nT=100] Saved progress: 916/1000 runs completed.
# Empirical FPR @ alpha=0.05: 0.045 | total run : 421 | cnt: 19 | not signal: 0
#   [nT=100] Saved progress: 917/1000 runs completed.
# Empirical FPR @ alpha=0.05: 0.045 | total run : 421 | cnt: 19 | not signal: 0
#   [nT=100] Saved progress: 918/1000 runs completed.
# Empirical FPR @ alpha=0.05: 0.045 | total run : 422 | cnt: 19 | not signal: 0
#   [nT=100] Saved progress: 919/1000 runs completed.
# Empirical FPR @ alpha=0.05: 0.045 | total run : 422 | cnt: 19 | not signal: 0
#   [nT=100] Saved progress: 920/1000 runs completed.
# Empirical FPR @ alpha=0.05: 0.045 | total run : 423 | cnt: 19 | not signal: 0
#   [nT=100] Saved progress: 921/1000 runs completed.
# Empirical FPR @ alpha=0.05: 0.045 | total run : 423 | cnt: 19 | not signal: 0
#   [nT=100] Saved progress: 922/1000 runs completed.
# Empirical FPR @ alpha=0.05: 0.045 | total run : 423 | cnt: 19 | not signal: 0
#   [nT=100] Saved progress: 923/1000 runs completed.
# Empirical FPR @ alpha=0.05: 0.045 | total run : 424 | cnt: 19 | not signal: 0
#   [nT=100] Saved progress: 924/1000 runs completed.
# Empirical FPR @ alpha=0.05: 0.045 | total run : 424 | cnt: 19 | not signal: 0
#   [nT=100] Saved progress: 925/1000 runs completed.
# Empirical FPR @ alpha=0.05: 0.045 | total run : 424 | cnt: 19 | not signal: 0
#   [nT=100] Saved progress: 926/1000 runs completed.
# Empirical FPR @ alpha=0.05: 0.045 | total run : 425 | cnt: 19 | not signal: 0
#   [nT=100] Saved progress: 927/1000 runs completed.
# Empirical FPR @ alpha=0.05: 0.045 | total run : 426 | cnt: 19 | not signal: 0
#   [nT=100] Saved progress: 928/1000 runs completed.
# Empirical FPR @ alpha=0.05: 0.045 | total run : 426 | cnt: 19 | not signal: 0
#   [nT=100] Saved progress: 929/1000 runs completed.
# Empirical FPR @ alpha=0.05: 0.044 | total run : 427 | cnt: 19 | not signal: 0
#   [nT=100] Saved progress: 930/1000 runs completed.
# Empirical FPR @ alpha=0.05: 0.044 | total run : 428 | cnt: 19 | not signal: 0
#   [nT=100] Saved progress: 931/1000 runs completed.
# Empirical FPR @ alpha=0.05: 0.044 | total run : 429 | cnt: 19 | not signal: 0
#   [nT=100] Saved progress: 932/1000 runs completed.
# Empirical FPR @ alpha=0.05: 0.044 | total run : 430 | cnt: 19 | not signal: 0
#   [nT=100] Saved progress: 933/1000 runs completed.
# Empirical FPR @ alpha=0.05: 0.044 | total run : 430 | cnt: 19 | not signal: 0
#   [nT=100] Saved progress: 934/1000 runs completed.
# Empirical FPR @ alpha=0.05: 0.044 | total run : 430 | cnt: 19 | not signal: 0
#   [nT=100] Saved progress: 935/1000 runs completed.
# Empirical FPR @ alpha=0.05: 0.044 | total run : 431 | cnt: 19 | not signal: 0
#   [nT=100] Saved progress: 936/1000 runs completed.
# Empirical FPR @ alpha=0.05: 0.044 | total run : 432 | cnt: 19 | not signal: 0
#   [nT=100] Saved progress: 937/1000 runs completed.
# Empirical FPR @ alpha=0.05: 0.046 | total run : 433 | cnt: 20 | not signal: 0
#   [nT=100] Saved progress: 938/1000 runs completed.
# Empirical FPR @ alpha=0.05: 0.046 | total run : 434 | cnt: 20 | not signal: 0
#   [nT=100] Saved progress: 939/1000 runs completed.
# Empirical FPR @ alpha=0.05: 0.046 | total run : 435 | cnt: 20 | not signal: 0
#   [nT=100] Saved progress: 940/1000 runs completed.
# Empirical FPR @ alpha=0.05: 0.046 | total run : 436 | cnt: 20 | not signal: 0
#   [nT=100] Saved progress: 941/1000 runs completed.
# Empirical FPR @ alpha=0.05: 0.046 | total run : 437 | cnt: 20 | not signal: 0
#   [nT=100] Saved progress: 942/1000 runs completed.
# Empirical FPR @ alpha=0.05: 0.046 | total run : 438 | cnt: 20 | not signal: 0
#   [nT=100] Saved progress: 943/1000 runs completed.
# Empirical FPR @ alpha=0.05: 0.046 | total run : 439 | cnt: 20 | not signal: 0
#   [nT=100] Saved progress: 944/1000 runs completed.
# Empirical FPR @ alpha=0.05: 0.046 | total run : 439 | cnt: 20 | not signal: 0
#   [nT=100] Saved progress: 945/1000 runs completed.
# Empirical FPR @ alpha=0.05: 0.046 | total run : 439 | cnt: 20 | not signal: 0
#   [nT=100] Saved progress: 946/1000 runs completed.
# Empirical FPR @ alpha=0.05: 0.045 | total run : 440 | cnt: 20 | not signal: 0
#   [nT=100] Saved progress: 947/1000 runs completed.
# Empirical FPR @ alpha=0.05: 0.045 | total run : 440 | cnt: 20 | not signal: 0
#   [nT=100] Saved progress: 948/1000 runs completed.
# Empirical FPR @ alpha=0.05: 0.045 | total run : 440 | cnt: 20 | not signal: 0
#   [nT=100] Saved progress: 949/1000 runs completed.
# Empirical FPR @ alpha=0.05: 0.045 | total run : 441 | cnt: 20 | not signal: 0
#   [nT=100] Saved progress: 950/1000 runs completed.
# Empirical FPR @ alpha=0.05: 0.045 | total run : 441 | cnt: 20 | not signal: 0
#   [nT=100] Saved progress: 951/1000 runs completed.
# Empirical FPR @ alpha=0.05: 0.045 | total run : 442 | cnt: 20 | not signal: 0
#   [nT=100] Saved progress: 952/1000 runs completed.
# Empirical FPR @ alpha=0.05: 0.045 | total run : 443 | cnt: 20 | not signal: 0
#   [nT=100] Saved progress: 953/1000 runs completed.
# Empirical FPR @ alpha=0.05: 0.045 | total run : 444 | cnt: 20 | not signal: 0
#   [nT=100] Saved progress: 954/1000 runs completed.
# Empirical FPR @ alpha=0.05: 0.045 | total run : 444 | cnt: 20 | not signal: 0
#   [nT=100] Saved progress: 955/1000 runs completed.
# Empirical FPR @ alpha=0.05: 0.045 | total run : 445 | cnt: 20 | not signal: 0
#   [nT=100] Saved progress: 956/1000 runs completed.
# Empirical FPR @ alpha=0.05: 0.047 | total run : 446 | cnt: 21 | not signal: 0
#   [nT=100] Saved progress: 957/1000 runs completed.
# Empirical FPR @ alpha=0.05: 0.047 | total run : 447 | cnt: 21 | not signal: 0
#   [nT=100] Saved progress: 958/1000 runs completed.
# Empirical FPR @ alpha=0.05: 0.047 | total run : 447 | cnt: 21 | not signal: 0
#   [nT=100] Saved progress: 959/1000 runs completed.
# Empirical FPR @ alpha=0.05: 0.047 | total run : 448 | cnt: 21 | not signal: 0
#   [nT=100] Saved progress: 960/1000 runs completed.
# Empirical FPR @ alpha=0.05: 0.047 | total run : 448 | cnt: 21 | not signal: 0
#   [nT=100] Saved progress: 961/1000 runs completed.
# Empirical FPR @ alpha=0.05: 0.047 | total run : 449 | cnt: 21 | not signal: 0
#   [nT=100] Saved progress: 962/1000 runs completed.
# Empirical FPR @ alpha=0.05: 0.047 | total run : 449 | cnt: 21 | not signal: 0
#   [nT=100] Saved progress: 963/1000 runs completed.
# Empirical FPR @ alpha=0.05: 0.047 | total run : 450 | cnt: 21 | not signal: 0
#   [nT=100] Saved progress: 964/1000 runs completed.
# Empirical FPR @ alpha=0.05: 0.047 | total run : 450 | cnt: 21 | not signal: 0
#   [nT=100] Saved progress: 965/1000 runs completed.
# Empirical FPR @ alpha=0.05: 0.047 | total run : 451 | cnt: 21 | not signal: 0
#   [nT=100] Saved progress: 966/1000 runs completed.
# Empirical FPR @ alpha=0.05: 0.046 | total run : 452 | cnt: 21 | not signal: 0
#   [nT=100] Saved progress: 967/1000 runs completed.
# Empirical FPR @ alpha=0.05: 0.046 | total run : 453 | cnt: 21 | not signal: 0
#   [nT=100] Saved progress: 968/1000 runs completed.
# Empirical FPR @ alpha=0.05: 0.046 | total run : 453 | cnt: 21 | not signal: 0
#   [nT=100] Saved progress: 969/1000 runs completed.
# Empirical FPR @ alpha=0.05: 0.046 | total run : 454 | cnt: 21 | not signal: 0
#   [nT=100] Saved progress: 970/1000 runs completed.
# Empirical FPR @ alpha=0.05: 0.046 | total run : 455 | cnt: 21 | not signal: 0
#   [nT=100] Saved progress: 971/1000 runs completed.
# Empirical FPR @ alpha=0.05: 0.046 | total run : 455 | cnt: 21 | not signal: 0
#   [nT=100] Saved progress: 972/1000 runs completed.
# Empirical FPR @ alpha=0.05: 0.046 | total run : 455 | cnt: 21 | not signal: 0
#   [nT=100] Saved progress: 973/1000 runs completed.
# Empirical FPR @ alpha=0.05: 0.046 | total run : 456 | cnt: 21 | not signal: 0
#   [nT=100] Saved progress: 974/1000 runs completed.
# Empirical FPR @ alpha=0.05: 0.046 | total run : 457 | cnt: 21 | not signal: 0
#   [nT=100] Saved progress: 975/1000 runs completed.
# Empirical FPR @ alpha=0.05: 0.046 | total run : 457 | cnt: 21 | not signal: 0
#   [nT=100] Saved progress: 976/1000 runs completed.
# Empirical FPR @ alpha=0.05: 0.046 | total run : 458 | cnt: 21 | not signal: 0
#   [nT=100] Saved progress: 977/1000 runs completed.
# Empirical FPR @ alpha=0.05: 0.046 | total run : 458 | cnt: 21 | not signal: 0
#   [nT=100] Saved progress: 978/1000 runs completed.
# Empirical FPR @ alpha=0.05: 0.046 | total run : 458 | cnt: 21 | not signal: 0
#   [nT=100] Saved progress: 979/1000 runs completed.
# Empirical FPR @ alpha=0.05: 0.046 | total run : 459 | cnt: 21 | not signal: 0
#   [nT=100] Saved progress: 980/1000 runs completed.
# Empirical FPR @ alpha=0.05: 0.046 | total run : 460 | cnt: 21 | not signal: 0
#   [nT=100] Saved progress: 981/1000 runs completed.
# Empirical FPR @ alpha=0.05: 0.046 | total run : 461 | cnt: 21 | not signal: 0
#   [nT=100] Saved progress: 982/1000 runs completed.
# Empirical FPR @ alpha=0.05: 0.045 | total run : 462 | cnt: 21 | not signal: 0
#   [nT=100] Saved progress: 983/1000 runs completed.
# Empirical FPR @ alpha=0.05: 0.045 | total run : 463 | cnt: 21 | not signal: 0
#   [nT=100] Saved progress: 984/1000 runs completed.
# Empirical FPR @ alpha=0.05: 0.045 | total run : 464 | cnt: 21 | not signal: 0
#   [nT=100] Saved progress: 985/1000 runs completed.
# Empirical FPR @ alpha=0.05: 0.045 | total run : 464 | cnt: 21 | not signal: 0
#   [nT=100] Saved progress: 986/1000 runs completed.
# Empirical FPR @ alpha=0.05: 0.045 | total run : 465 | cnt: 21 | not signal: 0
#   [nT=100] Saved progress: 987/1000 runs completed.
# Empirical FPR @ alpha=0.05: 0.045 | total run : 466 | cnt: 21 | not signal: 0
#   [nT=100] Saved progress: 988/1000 runs completed.
# Empirical FPR @ alpha=0.05: 0.045 | total run : 467 | cnt: 21 | not signal: 0
#   [nT=100] Saved progress: 989/1000 runs completed.
# Empirical FPR @ alpha=0.05: 0.045 | total run : 467 | cnt: 21 | not signal: 0
#   [nT=100] Saved progress: 990/1000 runs completed.
# Empirical FPR @ alpha=0.05: 0.045 | total run : 467 | cnt: 21 | not signal: 0
#   [nT=100] Saved progress: 991/1000 runs completed.
# Empirical FPR @ alpha=0.05: 0.045 | total run : 468 | cnt: 21 | not signal: 0
#   [nT=100] Saved progress: 992/1000 runs completed.
# Empirical FPR @ alpha=0.05: 0.045 | total run : 469 | cnt: 21 | not signal: 0
#   [nT=100] Saved progress: 993/1000 runs completed.
# Empirical FPR @ alpha=0.05: 0.045 | total run : 469 | cnt: 21 | not signal: 0
#   [nT=100] Saved progress: 994/1000 runs completed.
# Empirical FPR @ alpha=0.05: 0.045 | total run : 470 | cnt: 21 | not signal: 0
#   [nT=100] Saved progress: 995/1000 runs completed.
# Empirical FPR @ alpha=0.05: 0.045 | total run : 471 | cnt: 21 | not signal: 0
#   [nT=100] Saved progress: 996/1000 runs completed.
# Empirical FPR @ alpha=0.05: 0.044 | total run : 472 | cnt: 21 | not signal: 0
#   [nT=100] Saved progress: 997/1000 runs completed.
# Empirical FPR @ alpha=0.05: 0.044 | total run : 473 | cnt: 21 | not signal: 0
#   [nT=100] Saved progress: 998/1000 runs completed.
# Empirical FPR @ alpha=0.05: 0.044 | total run : 474 | cnt: 21 | not signal: 0
#   [nT=100] Saved progress: 999/1000 runs completed.
# Empirical FPR @ alpha=0.05: 0.044 | total run : 475 | cnt: 21 | not signal: 0
#   [nT=100] Saved progress: 1000/1000 runs completed.
# Empirical FPR @ alpha=0.05: 0.044 | total run : 476 | cnt: 21 | not signal: 0

# %%
print("=== FPR Experiment Summary ===")
for current_nT in nT_list:
    filepath = get_save_path(p, nS, current_nT, K, lambda_sel, lambda0)
    j_values, pvals = load_progress(filepath)
    
    if not pvals:
        print(f"nT={current_nT}: No data found.")
        continue
    
    pvals_arr = np.asarray(pvals)
    # Tính FPR: tỉ lệ số lần p-value <= alpha
    rejection_rate = (pvals_arr <= alpha).mean()
    print(f"nT={current_nT}: {len(pvals)} valid runs | Empirical FPR @ alpha={alpha}: {rejection_rate:.3f}")
# Out:
# === FPR Experiment Summary ===
# nT=50: 1000 valid runs | Empirical FPR @ alpha=0.05: 0.043
# nT=75: 981 valid runs | Empirical FPR @ alpha=0.05: 0.047
# nT=100: 700 valid runs | Empirical FPR @ alpha=0.05: 0.043
