# %% [markdown]
# # FPR Experiment for Adaptive CoRT-SI across different nT
# This notebook tests the false positive rate (FPR) of Adaptive CoRT-SI across varying target sample sizes (`nT`). It supports resumability, meaning if the execution is interrupted, it can pick up exactly where it left off by reading the saved `.npz` files.

# %%
from pathlib import Path
import sys

import numpy as np

cwd = Path.cwd().resolve()
candidates = [cwd, cwd.parent]
REPO_ROOT = next((candidate for candidate in candidates if (candidate / "cort_si").exists()), None)
if REPO_ROOT is None:
    raise RuntimeError("Could not locate the repo root containing the cort_si package.")
if str(REPO_ROOT) not in sys.path:
    sys.path.insert(0, str(REPO_ROOT))

from cort_si import SI_parallel_randj, SI_randj, gen_data

RESULTS_DIR = REPO_ROOT / "run_experiment" / "results"
RESULTS_DIR.mkdir(parents=True, exist_ok=True)

# %%
p = 300
nS = 120
num_info_aux = 3
num_uninfo_aux = 2
K = num_info_aux + num_uninfo_aux
lambda_sel = 0.6
lambda0 = 0.7
T = 5
nT_list = [75, 100, 50]

num_runs = 1000
base_seed = 0
alpha = 0.05
true_beta_scale = 1.0
rho = 0.0
sigma_noise = 1.0
source_shift_sd = 0.3
covariate_shift = False
save_interval = 1

print(f"num_runs = {num_runs}")
print(f"fixed alpha = {alpha}")
print(f"Null model true_beta scale = {true_beta_scale}")
print(f"K = {K}, p = {p}, nS = {nS}")
print(f"Testing nT values: {nT_list}")
# Out:
# num_runs = 1000
# fixed alpha = 0.05
# Null model true_beta scale = 1.0
# K = 5, p = 300, nS = 120
# Testing nT values: [75, 100, 50]

# %%
def generate_null_instance(nT_val, iteration_seed):
    return gen_data.generate_data(
        p=p,
        nS=nS,
        nT=nT_val,
        K=K,
        true_beta=true_beta_scale,
        rho=rho,
        sigma_noise=sigma_noise,
        source_shift_sd=source_shift_sd,
        covariate_shift=covariate_shift,
        seed=iteration_seed,
        num_info_aux=num_info_aux,
        num_uninfo_aux= num_uninfo_aux
    )

def get_save_path(p_val, nS_val, nT_val, K, lambda_sel, lambda0):
    return RESULTS_DIR / f"tpr_p{p_val}_nS{nS_val}_nT{nT_val}_K{K}_lamsel{lambda_sel}_lam0{lambda0}.npz"

import numpy as np

def load_progress(filepath):
    if filepath.exists():
        data = np.load(filepath)
        # Hỗ trợ cả file cũ (chỉ có null_pvalues) và file mới (có thêm j_values)
        if 'j_values' in data and 'null_pvalues' in data:
            return list(data['j_values']), list(data['null_pvalues'])
        elif 'null_pvalues' in data:
            return [], list(data['null_pvalues'])
    return [], []

def save_progress(filepath, j_values, null_pvalues, p_val, nS_val, nT_val, num_runs_val, alpha_val):
    np.savez(
        filepath,
        j_values=np.asarray(j_values, dtype=int),
        null_pvalues=np.asarray(null_pvalues, dtype=float),
        p=np.asarray([p_val], dtype=int),
        nS=np.asarray([nS_val], dtype=int),
        nT=np.asarray([nT_val], dtype=int),
        num_runs=np.asarray([num_runs_val], dtype=int),
        alpha=np.asarray([alpha_val], dtype=float),
    )

# %%
def run_resumable_fpr_experiment(nT_val, total_runs, seed_base, save_intvl=10):
    filepath = get_save_path(p, nS, nT_val, K, lambda_sel, lambda0)
    j_values, null_pvalues = load_progress(filepath)
    start_iteration = len(null_pvalues)
    
    if start_iteration >= total_runs:
        print(f"Experiment for nT={nT_val} already completed ({total_runs} runs).")
        return j_values, null_pvalues
    
    print(f"Starting/Resuming experiment for nT={nT_val} from run {start_iteration}/{total_runs}...")
    cnt = 0
    sum = 0
    mau = 0
    for iteration in range(start_iteration, total_runs):
        data_seed = seed_base + iteration
        XS_list, YS_list, X0, Y0, _, SigmaS_list, Sigma0, _ = generate_null_instance(nT_val, data_seed)
        lambdak_list = [lambda0] * len(XS_list)

        # SI_parallel_randj giờ trả về (j, p_sel) hoặc None
        result = SI_randj(
            X0,
            Y0,
            XS_list,
            YS_list,
            lambda_sel=lambda_sel,
            lambda0=lambda0,
            lambdak_list=lambdak_list,
            SigmaS_list=SigmaS_list,
            Sigma0=Sigma0,
            T=T,
            verbose=False,
        )

        if result is not None:
            j_val, p_sel = result
            if p_sel is not None and np.isfinite(p_sel):
                if j_val <= 5:
                    if p_sel <= alpha:
                        cnt += 1
                    sum += 1
                mau += 1
                j_values.append(int(j_val))
                null_pvalues.append(float(p_sel))

        if (iteration + 1) % save_intvl == 0 or (iteration + 1) == total_runs:
            save_progress(filepath, j_values, null_pvalues, p, nS, nT_val, total_runs, alpha)
            print(f"  [nT={nT_val}] Saved progress: {iteration + 1}/{total_runs} runs completed.")
            if sum > 0:
                print(f"Empirical TPR @ alpha={alpha}: {(cnt / sum):.3f} | total run : {sum} | cnt: {cnt} | not signal: {mau - sum} ")

    return j_values, null_pvalues

# %%
for current_nT in nT_list:
    run_resumable_fpr_experiment(current_nT, num_runs, base_seed, save_intvl=save_interval)
# Out:
# Starting/Resuming experiment for nT=75 from run 950/1000...
# length of M_obs: 1
# selected j: 4
# 0
# 1
# 2
# 3
# 4
# length of intervals: 2, length of intervals_model: 2
#   [nT=75] Saved progress: 951/1000 runs completed.
# Empirical TPR @ alpha=0.05: 0.000 | total run : 1 | cnt: 0 | not signal: 0
# length of M_obs: 9
# selected j: 2
# 0
# 1
# 2
# 3
# 4
# length of intervals: 1, length of intervals_model: 1
#   [nT=75] Saved progress: 952/1000 runs completed.
# Empirical TPR @ alpha=0.05: 0.000 | total run : 2 | cnt: 0 | not signal: 0
# length of M_obs: 6
# selected j: 1
# 0
# 1
# 2
# 3
# 4
# length of intervals: 1, length of intervals_model: 1
#   [nT=75] Saved progress: 953/1000 runs completed.
# Empirical TPR @ alpha=0.05: 0.000 | total run : 3 | cnt: 0 | not signal: 0
# length of M_obs: 6
# selected j: 2
# 0
# 1
# 2
# 3
# 4
# length of intervals: 1, length of intervals_model: 1
#   [nT=75] Saved progress: 954/1000 runs completed.
# Empirical TPR @ alpha=0.05: 0.250 | total run : 4 | cnt: 1 | not signal: 0
# length of M_obs: 4
# selected j: 4
# 0
# 1
# 2
# 3
# 4
# length of intervals: 1, length of intervals_model: 1
#   [nT=75] Saved progress: 955/1000 runs completed.
# Empirical TPR @ alpha=0.05: 0.400 | total run : 5 | cnt: 2 | not signal: 0
# length of M_obs: 5
# selected j: 4
# 0
# 1
# 2
# 3
# 4
# length of intervals: 1, length of intervals_model: 1
#   [nT=75] Saved progress: 956/1000 runs completed.
# Empirical TPR @ alpha=0.05: 0.333 | total run : 6 | cnt: 2 | not signal: 0
# length of M_obs: 5
# selected j: 4
# 0
# 1
# 2
# 3
# 4
# length of intervals: 1, length of intervals_model: 1
#   [nT=75] Saved progress: 957/1000 runs completed.
# Empirical TPR @ alpha=0.05: 0.429 | total run : 7 | cnt: 3 | not signal: 0
# length of M_obs: 5
# selected j: 1
# 0
# 1
# 2
# 3
# 4
# length of intervals: 2, length of intervals_model: 2
#   [nT=75] Saved progress: 958/1000 runs completed.
# Empirical TPR @ alpha=0.05: 0.375 | total run : 8 | cnt: 3 | not signal: 0
# length of M_obs: 7
# selected j: 3
# 0
# 1
# 2
# 3
# 4
# length of intervals: 1, length of intervals_model: 1
#   [nT=75] Saved progress: 959/1000 runs completed.
# Empirical TPR @ alpha=0.05: 0.333 | total run : 9 | cnt: 3 | not signal: 0
# length of M_obs: 9
# selected j: 1
# 0
# 1
# 2
# 3
# 4
# length of intervals: 1, length of intervals_model: 1
#   [nT=75] Saved progress: 960/1000 runs completed.
# Empirical TPR @ alpha=0.05: 0.300 | total run : 10 | cnt: 3 | not signal: 0
# length of M_obs: 4
# selected j: 0
# 0
# 1
# 2
# 3
# 4
# length of intervals: 1, length of intervals_model: 1
#   [nT=75] Saved progress: 961/1000 runs completed.
# Empirical TPR @ alpha=0.05: 0.273 | total run : 11 | cnt: 3 | not signal: 0
# length of M_obs: 5
# selected j: 1
# 0
# 1
# 2
# 3
# 4
# length of intervals: 1, length of intervals_model: 1
#   [nT=75] Saved progress: 962/1000 runs completed.
# Empirical TPR @ alpha=0.05: 0.250 | total run : 12 | cnt: 3 | not signal: 0
# length of M_obs: 5
# selected j: 3
# 0
# 1
# 2
# 3
# 4
# length of intervals: 1, length of intervals_model: 1
#   [nT=75] Saved progress: 963/1000 runs completed.
# Empirical TPR @ alpha=0.05: 0.308 | total run : 13 | cnt: 4 | not signal: 0
# length of M_obs: 5
# selected j: 3
# 0
# 1
# 2
# 3
# 4
# length of intervals: 1, length of intervals_model: 1
#   [nT=75] Saved progress: 964/1000 runs completed.
# Empirical TPR @ alpha=0.05: 0.286 | total run : 14 | cnt: 4 | not signal: 0
# length of M_obs: 6
# selected j: 240
# 0
# 1
# 2
# 3
# 4
# length of intervals: 1, length of intervals_model: 1
#   [nT=75] Saved progress: 965/1000 runs completed.
# Empirical TPR @ alpha=0.05: 0.286 | total run : 14 | cnt: 4 | not signal: 1
# length of M_obs: 7
# selected j: 3
# 0
# 1
# 2
# 3
# 4
# length of intervals: 1, length of intervals_model: 1
#   [nT=75] Saved progress: 966/1000 runs completed.
# Empirical TPR @ alpha=0.05: 0.267 | total run : 15 | cnt: 4 | not signal: 1
# length of M_obs: 5
# selected j: 0
# 0
# 1
# 2
# 3
# 4
# length of intervals: 3, length of intervals_model: 3
#   [nT=75] Saved progress: 967/1000 runs completed.
# Empirical TPR @ alpha=0.05: 0.250 | total run : 16 | cnt: 4 | not signal: 1
# length of M_obs: 5
# selected j: 4
# 0
# 1
# 2
# 3
# 4
# length of intervals: 3, length of intervals_model: 3
#   [nT=75] Saved progress: 968/1000 runs completed.
# Empirical TPR @ alpha=0.05: 0.294 | total run : 17 | cnt: 5 | not signal: 1
# length of M_obs: 4
# selected j: 1
# 0
# 1
# 2
# 3
# 4
# length of intervals: 1, length of intervals_model: 1
#   [nT=75] Saved progress: 969/1000 runs completed.
# Empirical TPR @ alpha=0.05: 0.278 | total run : 18 | cnt: 5 | not signal: 1
# length of M_obs: 5
# selected j: 0
# 0
# 1
# 2
# 3
# 4
# length of intervals: 1, length of intervals_model: 1
#   [nT=75] Saved progress: 970/1000 runs completed.
# Empirical TPR @ alpha=0.05: 0.263 | total run : 19 | cnt: 5 | not signal: 1
# length of M_obs: 6
# selected j: 1
# 0
# 1
# 2
# 3
# 4
# length of intervals: 1, length of intervals_model: 1
#   [nT=75] Saved progress: 971/1000 runs completed.
# Empirical TPR @ alpha=0.05: 0.250 | total run : 20 | cnt: 5 | not signal: 1
# length of M_obs: 0
#   [nT=75] Saved progress: 972/1000 runs completed.
# Empirical TPR @ alpha=0.05: 0.250 | total run : 20 | cnt: 5 | not signal: 1
# length of M_obs: 5
# selected j: 3
# 0
# 1
# 2
# 3
# 4

# %%
                                                                                                                                                                                        print("=== FPR Experiment Summary ===")
for current_nT in nT_list:
    filepath = get_save_path(p, nS, current_nT, K, lambda_sel, lambda0)
    j_values, pvals = load_progress(filepath)
    
    if not pvals:
        print(f"nT={current_nT}: No data found.")
        continue
    
    pvals_arr = np.asarray(pvals)
    # Tính FPR: tỉ lệ số lần p-value <= alpha
    rejection_rate = (pvals_arr <= alpha).mean()
    print(f"nT={current_nT}: {len(pvals)} valid runs | Empirical FPR @ alpha={alpha}: {rejection_rate:.3f}")
# Out:
# === FPR Experiment Summary ===
# nT=50: 222 valid runs | Empirical FPR @ alpha=0.05: 0.302
# nT=75: No data found.
# nT=100: No data found.
