# %% [markdown]
# # TPR Experiment for Naive and Bonferroni across different nT
# This notebook tests the true positive rate (TPR) of Naive and Bonferroni methods across varying target sample sizes (`nT`). It supports resumability, meaning if the execution is interrupted, it can pick up exactly where it left off by reading the saved `.npz` files.

# %%
from pathlib import Path
import random
import sys

import matplotlib.pyplot as plt
import numpy as np
from scipy import stats

cwd = Path.cwd().resolve()
candidates = [cwd, cwd.parent]
REPO_ROOT = next((candidate for candidate in candidates if (candidate / "cort_si").exists()), None)
if REPO_ROOT is None:
    raise RuntimeError("Could not locate the repo root containing the cort_si package.")
if str(REPO_ROOT) not in sys.path:
    sys.path.insert(0, str(REPO_ROOT))

from cort_si import (
    adaptive_source_selection,
    construct_Y,
    construct_Sigma,
    construct_folds,
    construct_test_statistic,
    gen_data,
    solve_cort_model,
)

RESULTS_DIR = REPO_ROOT / "run_experiment" / "results"
RESULTS_DIR.mkdir(parents=True, exist_ok=True)

# %%
p = 300
nS = 120
num_info_aux = 3
num_uninfo_aux = 2
K = num_info_aux + num_uninfo_aux
lambda_sel = 0.6
lambda0 = 0.7
T = 5
nT_list = [50, 75, 100]


num_runs = 1200
base_seed = 0
alpha = 0.05
true_beta_scale = 1.0
rho = 0.0
sigma_noise = 1.0
source_shift_sd = 0.3
covariate_shift = False
save_interval = 1

bonf_log10_family_size = p * np.log10(2.0)

print(f"num_runs = {num_runs}")
print(f"fixed alpha = {alpha}")
print(f"Null model true_beta scale = {true_beta_scale}")
print(f"K = {K}, p = {p}, nS = {nS}")
print(f"Testing nT values: {nT_list}")
print(f"Bonferroni family size uses 2^p with p = {p} (about 10^{bonf_log10_family_size:.1f})")
# Out:
# num_runs = 1200
# fixed alpha = 0.05
# Null model true_beta scale = 1.0
# K = 5, p = 300, nS = 120
# Testing nT values: [50, 75, 100]
# Bonferroni family size uses 2^p with p = 300 (about 10^90.3)

# %%
def generate_null_instance(nT_val, iteration_seed):
    return gen_data.generate_data(
        p=p,
        nS=nS,
        nT=nT_val,
        K=K,
        true_beta=true_beta_scale,
        rho=rho,
        sigma_noise=sigma_noise,
        source_shift_sd=source_shift_sd,
        covariate_shift=covariate_shift,
        seed=iteration_seed,
        num_info_aux=num_info_aux,
        num_uninfo_aux=num_uninfo_aux
    )

def bonferroni_adjust_pvalue(naive_pvalue, num_features):
    if naive_pvalue is None or not np.isfinite(naive_pvalue):
        return np.nan
    if naive_pvalue <= 0.0:
        return 0.0

    log_adjusted = np.log(naive_pvalue) + (num_features * np.log(2.0))
    if log_adjusted >= 0.0:
        return 1.0
    return float(np.exp(log_adjusted))

def compute_random_selected_pvalues(X0, Y0, XS_list, YS_list, SigmaS_list, Sigma0, lambdak_list, feature_seed):
    folds = construct_folds(X0.shape[0], T=T, shuffle=False)
    I_obs = adaptive_source_selection(X0, Y0, XS_list, YS_list, folds, lambda_sel, verbose=False)
    _, beta0_hat, _, _ = solve_cort_model(
        X0,
        Y0,
        XS_list,
        YS_list,
        I_obs,
        lambda0,
        lambdak_list,
        verbose=False,
        label="Observed CoRT fit",
    )
    M_obs = [idx for idx, value in enumerate(beta0_hat) if value != 0]
    if not M_obs:
        return None

    feature_rng = random.Random(feature_seed)
    feature_idx = feature_rng.choice(M_obs)

    Y_obs = construct_Y(YS_list, Y0)
    Sigma = construct_Sigma(SigmaS_list, Sigma0)
    X0M = X0[:, M_obs]
    etaj, etajTy = construct_test_statistic(feature_idx, X0M, Y_obs, M_obs, Y0.shape[0], Y_obs.shape[0])

    variance = float(np.asarray(etaj.T @ Sigma @ etaj).item())
    if not np.isfinite(variance) or variance <= 0.0:
        return None

    z_score = float(etajTy / np.sqrt(variance))
    naive_pvalue = float(2.0 * stats.norm.sf(abs(z_score)))
    bonf_pvalue = bonferroni_adjust_pvalue(naive_pvalue, X0.shape[1])

    return {
        "feature_idx": int(feature_idx),
        "naive_pvalue": naive_pvalue,
        "bonf_pvalue": bonf_pvalue,
    }

def get_save_paths(p_val, nS_val, nT_val, K, lambda_sel, lambda0):
    naive_path = RESULTS_DIR / f"naive_tpr_p{p_val}_nS{nS_val}_nT{nT_val}_K{K}_lamsel{lambda_sel}_lam0{lambda0}.npz"
    bonf_path = RESULTS_DIR / f"bonf_tpr_p{p_val}_nS{nS_val}_nT{nT_val}_K{K}_lamsel{lambda_sel}_lam0{lambda0}.npz"
    return naive_path, bonf_path

def load_progress(filepath):
    if filepath.exists():
        data = np.load(filepath)
        if 'j_values' in data and 'null_pvalues' in data:
            return list(data['j_values']), list(data['null_pvalues'])
        elif 'null_pvalues' in data:
            return [], list(data['null_pvalues'])
    return [], []

def save_progress(filepath, j_values, null_pvalues, p_val, nS_val, nT_val, num_runs_val, alpha_val):
    np.savez(
        filepath,
        j_values=np.asarray(j_values, dtype=int),
        null_pvalues=np.asarray(null_pvalues, dtype=float),
        p=np.asarray([p_val], dtype=int),
        nS=np.asarray([nS_val], dtype=int),
        nT=np.asarray([nT_val], dtype=int),
        num_runs=np.asarray([num_runs_val], dtype=int),
        alpha=np.asarray([alpha_val], dtype=float),
    )

# %%
def run_resumable_tpr_experiment(nT_val, total_runs, seed_base, save_intvl=10):
    naive_path, bonf_path = get_save_paths(p, nS, nT_val, K, lambda_sel, lambda0)
    
    naive_j, naive_pvalues = load_progress(naive_path)
    bonf_j, bonf_pvalues = load_progress(bonf_path)
    
    start_iteration = len(naive_pvalues)
    
    if start_iteration >= total_runs:
        print(f"Experiment for nT={nT_val} already completed ({total_runs} runs).")
        return naive_j, naive_pvalues, bonf_j, bonf_pvalues
    
    print(f"Starting/Resuming experiment for nT={nT_val} from run {start_iteration}/{total_runs}...")
    cnt_naive = 0
    cnt_bonf = 0
    sum_valid = 0
    mau = 0
    
    for iteration in range(start_iteration, total_runs):
        data_seed = seed_base + iteration
        XS_list, YS_list, X0, Y0, _, SigmaS_list, Sigma0, _ = generate_null_instance(nT_val, data_seed)
        lambdak_list = [lambda0] * len(XS_list)

        pvalue_record = compute_random_selected_pvalues(
            X0,
            Y0,
            XS_list,
            YS_list,
            SigmaS_list,
            Sigma0,
            lambdak_list,
            feature_seed=data_seed,
        )

        if pvalue_record is not None:
            naive_p_val = pvalue_record["naive_pvalue"]
            bonf_p_val = pvalue_record["bonf_pvalue"]
            feat_idx = pvalue_record["feature_idx"]
            
            if np.isfinite(naive_p_val):
                if feat_idx <= 5:
                    if naive_p_val <= alpha:
                        cnt_naive += 1
                    if bonf_p_val <= alpha:
                        cnt_bonf += 1
                    sum_valid += 1
                mau += 1
                
                naive_pvalues.append(naive_p_val)
                naive_j.append(feat_idx)
                bonf_pvalues.append(bonf_p_val)
                bonf_j.append(feat_idx)

        if (iteration + 1) % save_intvl == 0 or (iteration + 1) == total_runs:
            save_progress(naive_path, naive_j, naive_pvalues, p, nS, nT_val, total_runs, alpha)
            save_progress(bonf_path, bonf_j, bonf_pvalues, p, nS, nT_val, total_runs, alpha)
            print(f"  [nT={nT_val}] Saved progress: {iteration + 1}/{total_runs} iterations processed.")
            if sum_valid > 0:
                print(f"Empirical TPR @ alpha={alpha}: Naive={(cnt_naive / sum_valid):.3f}, Bonf={(cnt_bonf / sum_valid):.3f} | valid signal runs: {sum_valid} | not signal: {mau - sum_valid}")

    return naive_j, naive_pvalues, bonf_j, bonf_pvalues

# %%
for current_nT in nT_list:
    run_resumable_tpr_experiment(current_nT, num_runs, base_seed, save_intvl=save_interval)
# Out:
# Starting/Resuming experiment for nT=50 from run 1184/1300...
#   [nT=50] Saved progress: 1185/1300 iterations processed.
#   [nT=50] Saved progress: 1186/1300 iterations processed.
#   [nT=50] Saved progress: 1187/1300 iterations processed.
# Empirical TPR @ alpha=0.05: Naive=1.000, Bonf=0.000 | valid signal runs: 1 | not signal: 0
#   [nT=50] Saved progress: 1188/1300 iterations processed.
# Empirical TPR @ alpha=0.05: Naive=0.500, Bonf=0.000 | valid signal runs: 2 | not signal: 0
#   [nT=50] Saved progress: 1189/1300 iterations processed.
# Empirical TPR @ alpha=0.05: Naive=0.667, Bonf=0.000 | valid signal runs: 3 | not signal: 0
#   [nT=50] Saved progress: 1190/1300 iterations processed.
# Empirical TPR @ alpha=0.05: Naive=0.667, Bonf=0.000 | valid signal runs: 3 | not signal: 1
#   [nT=50] Saved progress: 1191/1300 iterations processed.
# Empirical TPR @ alpha=0.05: Naive=0.667, Bonf=0.000 | valid signal runs: 3 | not signal: 1
#   [nT=50] Saved progress: 1192/1300 iterations processed.
# Empirical TPR @ alpha=0.05: Naive=0.750, Bonf=0.000 | valid signal runs: 4 | not signal: 1
#   [nT=50] Saved progress: 1193/1300 iterations processed.
# Empirical TPR @ alpha=0.05: Naive=0.750, Bonf=0.000 | valid signal runs: 4 | not signal: 1
#   [nT=50] Saved progress: 1194/1300 iterations processed.
# Empirical TPR @ alpha=0.05: Naive=0.600, Bonf=0.000 | valid signal runs: 5 | not signal: 1
#   [nT=50] Saved progress: 1195/1300 iterations processed.
# Empirical TPR @ alpha=0.05: Naive=0.667, Bonf=0.000 | valid signal runs: 6 | not signal: 1
#   [nT=50] Saved progress: 1196/1300 iterations processed.
# Empirical TPR @ alpha=0.05: Naive=0.571, Bonf=0.000 | valid signal runs: 7 | not signal: 1
#   [nT=50] Saved progress: 1197/1300 iterations processed.
# Empirical TPR @ alpha=0.05: Naive=0.500, Bonf=0.000 | valid signal runs: 8 | not signal: 1
#   [nT=50] Saved progress: 1198/1300 iterations processed.
# Empirical TPR @ alpha=0.05: Naive=0.444, Bonf=0.000 | valid signal runs: 9 | not signal: 1
#   [nT=50] Saved progress: 1199/1300 iterations processed.
# Empirical TPR @ alpha=0.05: Naive=0.500, Bonf=0.000 | valid signal runs: 10 | not signal: 1
#   [nT=50] Saved progress: 1200/1300 iterations processed.
# Empirical TPR @ alpha=0.05: Naive=0.500, Bonf=0.000 | valid signal runs: 10 | not signal: 2
#   [nT=50] Saved progress: 1201/1300 iterations processed.
# Empirical TPR @ alpha=0.05: Naive=0.455, Bonf=0.000 | valid signal runs: 11 | not signal: 2
#   [nT=50] Saved progress: 1202/1300 iterations processed.
# Empirical TPR @ alpha=0.05: Naive=0.455, Bonf=0.000 | valid signal runs: 11 | not signal: 2
#   [nT=50] Saved progress: 1203/1300 iterations processed.
# Empirical TPR @ alpha=0.05: Naive=0.417, Bonf=0.000 | valid signal runs: 12 | not signal: 2
#   [nT=50] Saved progress: 1204/1300 iterations processed.
# Empirical TPR @ alpha=0.05: Naive=0.417, Bonf=0.000 | valid signal runs: 12 | not signal: 2
#   [nT=50] Saved progress: 1205/1300 iterations processed.
# Empirical TPR @ alpha=0.05: Naive=0.417, Bonf=0.000 | valid signal runs: 12 | not signal: 2
#   [nT=50] Saved progress: 1206/1300 iterations processed.
# Empirical TPR @ alpha=0.05: Naive=0.417, Bonf=0.000 | valid signal runs: 12 | not signal: 3
#   [nT=50] Saved progress: 1207/1300 iterations processed.
# Empirical TPR @ alpha=0.05: Naive=0.417, Bonf=0.000 | valid signal runs: 12 | not signal: 4
#   [nT=50] Saved progress: 1208/1300 iterations processed.
# Empirical TPR @ alpha=0.05: Naive=0.385, Bonf=0.000 | valid signal runs: 13 | not signal: 4
#   [nT=50] Saved progress: 1209/1300 iterations processed.
# Empirical TPR @ alpha=0.05: Naive=0.357, Bonf=0.000 | valid signal runs: 14 | not signal: 4
#   [nT=50] Saved progress: 1210/1300 iterations processed.
# Empirical TPR @ alpha=0.05: Naive=0.333, Bonf=0.000 | valid signal runs: 15 | not signal: 4
#   [nT=50] Saved progress: 1211/1300 iterations processed.
# Empirical TPR @ alpha=0.05: Naive=0.375, Bonf=0.000 | valid signal runs: 16 | not signal: 4
#   [nT=50] Saved progress: 1212/1300 iterations processed.
# Empirical TPR @ alpha=0.05: Naive=0.412, Bonf=0.000 | valid signal runs: 17 | not signal: 4
#   [nT=50] Saved progress: 1213/1300 iterations processed.
# Empirical TPR @ alpha=0.05: Naive=0.444, Bonf=0.000 | valid signal runs: 18 | not signal: 4
#   [nT=50] Saved progress: 1214/1300 iterations processed.
# Empirical TPR @ alpha=0.05: Naive=0.474, Bonf=0.000 | valid signal runs: 19 | not signal: 4
#   [nT=50] Saved progress: 1215/1300 iterations processed.
# Empirical TPR @ alpha=0.05: Naive=0.450, Bonf=0.000 | valid signal runs: 20 | not signal: 4
#   [nT=50] Saved progress: 1216/1300 iterations processed.
# Empirical TPR @ alpha=0.05: Naive=0.476, Bonf=0.000 | valid signal runs: 21 | not signal: 4
#   [nT=50] Saved progress: 1217/1300 iterations processed.
# Empirical TPR @ alpha=0.05: Naive=0.455, Bonf=0.000 | valid signal runs: 22 | not signal: 4
#   [nT=50] Saved progress: 1218/1300 iterations processed.
# Empirical TPR @ alpha=0.05: Naive=0.455, Bonf=0.000 | valid signal runs: 22 | not signal: 4
#   [nT=50] Saved progress: 1219/1300 iterations processed.
# Empirical TPR @ alpha=0.05: Naive=0.478, Bonf=0.000 | valid signal runs: 23 | not signal: 4
#   [nT=50] Saved progress: 1220/1300 iterations processed.
# Empirical TPR @ alpha=0.05: Naive=0.500, Bonf=0.000 | valid signal runs: 24 | not signal: 4
#   [nT=50] Saved progress: 1221/1300 iterations processed.
# Empirical TPR @ alpha=0.05: Naive=0.500, Bonf=0.000 | valid signal runs: 24 | not signal: 4
#   [nT=50] Saved progress: 1222/1300 iterations processed.
# Empirical TPR @ alpha=0.05: Naive=0.480, Bonf=0.000 | valid signal runs: 25 | not signal: 4
#   [nT=50] Saved progress: 1223/1300 iterations processed.
# Empirical TPR @ alpha=0.05: Naive=0.480, Bonf=0.000 | valid signal runs: 25 | not signal: 5
#   [nT=50] Saved progress: 1224/1300 iterations processed.
# Empirical TPR @ alpha=0.05: Naive=0.480, Bonf=0.000 | valid signal runs: 25 | not signal: 6
#   [nT=50] Saved progress: 1225/1300 iterations processed.
# Empirical TPR @ alpha=0.05: Naive=0.462, Bonf=0.000 | valid signal runs: 26 | not signal: 6
#   [nT=50] Saved progress: 1226/1300 iterations processed.
# Empirical TPR @ alpha=0.05: Naive=0.481, Bonf=0.000 | valid signal runs: 27 | not signal: 6
#   [nT=50] Saved progress: 1227/1300 iterations processed.
# Empirical TPR @ alpha=0.05: Naive=0.481, Bonf=0.000 | valid signal runs: 27 | not signal: 7
#   [nT=50] Saved progress: 1228/1300 iterations processed.
# Empirical TPR @ alpha=0.05: Naive=0.464, Bonf=0.000 | valid signal runs: 28 | not signal: 7
#   [nT=50] Saved progress: 1229/1300 iterations processed.
# Empirical TPR @ alpha=0.05: Naive=0.483, Bonf=0.000 | valid signal runs: 29 | not signal: 7
#   [nT=50] Saved progress: 1230/1300 iterations processed.
# Empirical TPR @ alpha=0.05: Naive=0.500, Bonf=0.000 | valid signal runs: 30 | not signal: 7
#   [nT=50] Saved progress: 1231/1300 iterations processed.
# Empirical TPR @ alpha=0.05: Naive=0.500, Bonf=0.000 | valid signal runs: 30 | not signal: 8
#   [nT=50] Saved progress: 1232/1300 iterations processed.
# Empirical TPR @ alpha=0.05: Naive=0.516, Bonf=0.000 | valid signal runs: 31 | not signal: 8
#   [nT=50] Saved progress: 1233/1300 iterations processed.
# Empirical TPR @ alpha=0.05: Naive=0.516, Bonf=0.000 | valid signal runs: 31 | not signal: 8
#   [nT=50] Saved progress: 1234/1300 iterations processed.
# Empirical TPR @ alpha=0.05: Naive=0.500, Bonf=0.000 | valid signal runs: 32 | not signal: 8
#   [nT=50] Saved progress: 1235/1300 iterations processed.
# Empirical TPR @ alpha=0.05: Naive=0.515, Bonf=0.000 | valid signal runs: 33 | not signal: 8
#   [nT=50] Saved progress: 1236/1300 iterations processed.
# Empirical TPR @ alpha=0.05: Naive=0.515, Bonf=0.000 | valid signal runs: 33 | not signal: 9
#   [nT=50] Saved progress: 1237/1300 iterations processed.
# Empirical TPR @ alpha=0.05: Naive=0.515, Bonf=0.000 | valid signal runs: 33 | not signal: 10
#   [nT=50] Saved progress: 1238/1300 iterations processed.
# Empirical TPR @ alpha=0.05: Naive=0.529, Bonf=0.000 | valid signal runs: 34 | not signal: 10
#   [nT=50] Saved progress: 1239/1300 iterations processed.
# Empirical TPR @ alpha=0.05: Naive=0.543, Bonf=0.000 | valid signal runs: 35 | not signal: 10
#   [nT=50] Saved progress: 1240/1300 iterations processed.
# Empirical TPR @ alpha=0.05: Naive=0.556, Bonf=0.000 | valid signal runs: 36 | not signal: 10
#   [nT=50] Saved progress: 1241/1300 iterations processed.
# Empirical TPR @ alpha=0.05: Naive=0.556, Bonf=0.000 | valid signal runs: 36 | not signal: 11
#   [nT=50] Saved progress: 1242/1300 iterations processed.
# Empirical TPR @ alpha=0.05: Naive=0.556, Bonf=0.000 | valid signal runs: 36 | not signal: 12
#   [nT=50] Saved progress: 1243/1300 iterations processed.
# Empirical TPR @ alpha=0.05: Naive=0.556, Bonf=0.000 | valid signal runs: 36 | not signal: 12
#   [nT=50] Saved progress: 1244/1300 iterations processed.
# Empirical TPR @ alpha=0.05: Naive=0.568, Bonf=0.000 | valid signal runs: 37 | not signal: 12
#   [nT=50] Saved progress: 1245/1300 iterations processed.
# Empirical TPR @ alpha=0.05: Naive=0.579, Bonf=0.000 | valid signal runs: 38 | not signal: 12
#   [nT=50] Saved progress: 1246/1300 iterations processed.
# Empirical TPR @ alpha=0.05: Naive=0.590, Bonf=0.000 | valid signal runs: 39 | not signal: 12
#   [nT=50] Saved progress: 1247/1300 iterations processed.
# Empirical TPR @ alpha=0.05: Naive=0.600, Bonf=0.000 | valid signal runs: 40 | not signal: 12
#   [nT=50] Saved progress: 1248/1300 iterations processed.
# Empirical TPR @ alpha=0.05: Naive=0.610, Bonf=0.000 | valid signal runs: 41 | not signal: 12
#   [nT=50] Saved progress: 1249/1300 iterations processed.
# Empirical TPR @ alpha=0.05: Naive=0.610, Bonf=0.000 | valid signal runs: 41 | not signal: 13
#   [nT=50] Saved progress: 1250/1300 iterations processed.
# Empirical TPR @ alpha=0.05: Naive=0.619, Bonf=0.000 | valid signal runs: 42 | not signal: 13
#   [nT=50] Saved progress: 1251/1300 iterations processed.
# Empirical TPR @ alpha=0.05: Naive=0.605, Bonf=0.000 | valid signal runs: 43 | not signal: 13
#   [nT=50] Saved progress: 1252/1300 iterations processed.
# Empirical TPR @ alpha=0.05: Naive=0.614, Bonf=0.000 | valid signal runs: 44 | not signal: 13
#   [nT=50] Saved progress: 1253/1300 iterations processed.
# Empirical TPR @ alpha=0.05: Naive=0.600, Bonf=0.000 | valid signal runs: 45 | not signal: 13
#   [nT=50] Saved progress: 1254/1300 iterations processed.
# Empirical TPR @ alpha=0.05: Naive=0.600, Bonf=0.000 | valid signal runs: 45 | not signal: 14
#   [nT=50] Saved progress: 1255/1300 iterations processed.
# Empirical TPR @ alpha=0.05: Naive=0.587, Bonf=0.000 | valid signal runs: 46 | not signal: 14
#   [nT=50] Saved progress: 1256/1300 iterations processed.
# Empirical TPR @ alpha=0.05: Naive=0.574, Bonf=0.000 | valid signal runs: 47 | not signal: 14
#   [nT=50] Saved progress: 1257/1300 iterations processed.
# Empirical TPR @ alpha=0.05: Naive=0.583, Bonf=0.000 | valid signal runs: 48 | not signal: 14
#   [nT=50] Saved progress: 1258/1300 iterations processed.
# Empirical TPR @ alpha=0.05: Naive=0.583, Bonf=0.000 | valid signal runs: 48 | not signal: 15
#   [nT=50] Saved progress: 1259/1300 iterations processed.
# Empirical TPR @ alpha=0.05: Naive=0.571, Bonf=0.000 | valid signal runs: 49 | not signal: 15
#   [nT=50] Saved progress: 1260/1300 iterations processed.
# Empirical TPR @ alpha=0.05: Naive=0.560, Bonf=0.000 | valid signal runs: 50 | not signal: 15
#   [nT=50] Saved progress: 1261/1300 iterations processed.
# Empirical TPR @ alpha=0.05: Naive=0.569, Bonf=0.000 | valid signal runs: 51 | not signal: 15
#   [nT=50] Saved progress: 1262/1300 iterations processed.
# Empirical TPR @ alpha=0.05: Naive=0.577, Bonf=0.000 | valid signal runs: 52 | not signal: 15
#   [nT=50] Saved progress: 1263/1300 iterations processed.
# Empirical TPR @ alpha=0.05: Naive=0.566, Bonf=0.000 | valid signal runs: 53 | not signal: 15
#   [nT=50] Saved progress: 1264/1300 iterations processed.
# Empirical TPR @ alpha=0.05: Naive=0.574, Bonf=0.000 | valid signal runs: 54 | not signal: 15
#   [nT=50] Saved progress: 1265/1300 iterations processed.
# Empirical TPR @ alpha=0.05: Naive=0.582, Bonf=0.000 | valid signal runs: 55 | not signal: 15
#   [nT=50] Saved progress: 1266/1300 iterations processed.
# Empirical TPR @ alpha=0.05: Naive=0.571, Bonf=0.000 | valid signal runs: 56 | not signal: 15
#   [nT=50] Saved progress: 1267/1300 iterations processed.
# Empirical TPR @ alpha=0.05: Naive=0.571, Bonf=0.000 | valid signal runs: 56 | not signal: 15
#   [nT=50] Saved progress: 1268/1300 iterations processed.
# Empirical TPR @ alpha=0.05: Naive=0.579, Bonf=0.000 | valid signal runs: 57 | not signal: 15
#   [nT=50] Saved progress: 1269/1300 iterations processed.
# Empirical TPR @ alpha=0.05: Naive=0.569, Bonf=0.000 | valid signal runs: 58 | not signal: 15
#   [nT=50] Saved progress: 1270/1300 iterations processed.
# Empirical TPR @ alpha=0.05: Naive=0.576, Bonf=0.000 | valid signal runs: 59 | not signal: 15
#   [nT=50] Saved progress: 1271/1300 iterations processed.
# Empirical TPR @ alpha=0.05: Naive=0.576, Bonf=0.000 | valid signal runs: 59 | not signal: 16
#   [nT=50] Saved progress: 1272/1300 iterations processed.
# Empirical TPR @ alpha=0.05: Naive=0.567, Bonf=0.000 | valid signal runs: 60 | not signal: 16
#   [nT=50] Saved progress: 1273/1300 iterations processed.
# Empirical TPR @ alpha=0.05: Naive=0.574, Bonf=0.000 | valid signal runs: 61 | not signal: 16
#   [nT=50] Saved progress: 1274/1300 iterations processed.
# Empirical TPR @ alpha=0.05: Naive=0.574, Bonf=0.000 | valid signal runs: 61 | not signal: 17
#   [nT=50] Saved progress: 1275/1300 iterations processed.
# Empirical TPR @ alpha=0.05: Naive=0.565, Bonf=0.000 | valid signal runs: 62 | not signal: 17
#   [nT=50] Saved progress: 1276/1300 iterations processed.
# Empirical TPR @ alpha=0.05: Naive=0.556, Bonf=0.000 | valid signal runs: 63 | not signal: 17
#   [nT=50] Saved progress: 1277/1300 iterations processed.
# Empirical TPR @ alpha=0.05: Naive=0.547, Bonf=0.000 | valid signal runs: 64 | not signal: 17
#   [nT=50] Saved progress: 1278/1300 iterations processed.
# Empirical TPR @ alpha=0.05: Naive=0.547, Bonf=0.000 | valid signal runs: 64 | not signal: 17
#   [nT=50] Saved progress: 1279/1300 iterations processed.
# Empirical TPR @ alpha=0.05: Naive=0.554, Bonf=0.000 | valid signal runs: 65 | not signal: 17
#   [nT=50] Saved progress: 1280/1300 iterations processed.
# Empirical TPR @ alpha=0.05: Naive=0.554, Bonf=0.000 | valid signal runs: 65 | not signal: 18
#   [nT=50] Saved progress: 1281/1300 iterations processed.
# Empirical TPR @ alpha=0.05: Naive=0.554, Bonf=0.000 | valid signal runs: 65 | not signal: 18
#   [nT=50] Saved progress: 1282/1300 iterations processed.
# Empirical TPR @ alpha=0.05: Naive=0.545, Bonf=0.000 | valid signal runs: 66 | not signal: 18
#   [nT=50] Saved progress: 1283/1300 iterations processed.
# Empirical TPR @ alpha=0.05: Naive=0.537, Bonf=0.000 | valid signal runs: 67 | not signal: 18
#   [nT=50] Saved progress: 1284/1300 iterations processed.
# Empirical TPR @ alpha=0.05: Naive=0.537, Bonf=0.000 | valid signal runs: 67 | not signal: 18
#   [nT=50] Saved progress: 1285/1300 iterations processed.
# Empirical TPR @ alpha=0.05: Naive=0.529, Bonf=0.000 | valid signal runs: 68 | not signal: 18
#   [nT=50] Saved progress: 1286/1300 iterations processed.
# Empirical TPR @ alpha=0.05: Naive=0.536, Bonf=0.000 | valid signal runs: 69 | not signal: 18
#   [nT=50] Saved progress: 1287/1300 iterations processed.
# Empirical TPR @ alpha=0.05: Naive=0.543, Bonf=0.000 | valid signal runs: 70 | not signal: 18
#   [nT=50] Saved progress: 1288/1300 iterations processed.
# Empirical TPR @ alpha=0.05: Naive=0.549, Bonf=0.000 | valid signal runs: 71 | not signal: 18
#   [nT=50] Saved progress: 1289/1300 iterations processed.
# Empirical TPR @ alpha=0.05: Naive=0.556, Bonf=0.000 | valid signal runs: 72 | not signal: 18
#   [nT=50] Saved progress: 1290/1300 iterations processed.
# Empirical TPR @ alpha=0.05: Naive=0.548, Bonf=0.000 | valid signal runs: 73 | not signal: 18
#   [nT=50] Saved progress: 1291/1300 iterations processed.
# Empirical TPR @ alpha=0.05: Naive=0.548, Bonf=0.000 | valid signal runs: 73 | not signal: 19
#   [nT=50] Saved progress: 1292/1300 iterations processed.
# Empirical TPR @ alpha=0.05: Naive=0.548, Bonf=0.000 | valid signal runs: 73 | not signal: 20
#   [nT=50] Saved progress: 1293/1300 iterations processed.
# Empirical TPR @ alpha=0.05: Naive=0.541, Bonf=0.000 | valid signal runs: 74 | not signal: 20
#   [nT=50] Saved progress: 1294/1300 iterations processed.
# Empirical TPR @ alpha=0.05: Naive=0.533, Bonf=0.000 | valid signal runs: 75 | not signal: 20
#   [nT=50] Saved progress: 1295/1300 iterations processed.
# Empirical TPR @ alpha=0.05: Naive=0.526, Bonf=0.000 | valid signal runs: 76 | not signal: 20
#   [nT=50] Saved progress: 1296/1300 iterations processed.
# Empirical TPR @ alpha=0.05: Naive=0.526, Bonf=0.000 | valid signal runs: 76 | not signal: 20
#   [nT=50] Saved progress: 1297/1300 iterations processed.
# Empirical TPR @ alpha=0.05: Naive=0.526, Bonf=0.000 | valid signal runs: 76 | not signal: 21
#   [nT=50] Saved progress: 1298/1300 iterations processed.
# Empirical TPR @ alpha=0.05: Naive=0.532, Bonf=0.000 | valid signal runs: 77 | not signal: 21
#   [nT=50] Saved progress: 1299/1300 iterations processed.
# Empirical TPR @ alpha=0.05: Naive=0.532, Bonf=0.000 | valid signal runs: 77 | not signal: 21
#   [nT=50] Saved progress: 1300/1300 iterations processed.
# Empirical TPR @ alpha=0.05: Naive=0.526, Bonf=0.000 | valid signal runs: 78 | not signal: 21

# %%
print("=== TPR Experiment Summary ===")
for current_nT in nT_list:
    naive_path, bonf_path = get_save_paths(p, nS, current_nT, K, lambda_sel, lambda0)
    naive_j, naive_pvalues = load_progress(naive_path)
    bonf_j, bonf_pvalues = load_progress(bonf_path)
    
    if not naive_pvalues:
        print(f"nT={current_nT}: No data found.")
        continue
    
    naive_arr = np.asarray(naive_pvalues)
    naive_j_arr = np.asarray(naive_j)
    bonf_arr = np.asarray(bonf_pvalues)
    
    valid_indices = np.where(naive_j_arr <= 5)[0]
    if len(valid_indices) == 0:
        print(f"nT={current_nT}: No valid signal runs found.")
        continue
        
    naive_valid_arr = naive_arr[valid_indices]
    bonf_valid_arr = bonf_arr[valid_indices]
    
    naive_rejection_rate = (naive_valid_arr <= alpha).mean()
    bonf_rejection_rate = (bonf_valid_arr <= alpha).mean()
    print(f"nT={current_nT}: {len(naive_valid_arr)} valid signal runs | Naive TPR @ alpha={alpha}: {naive_rejection_rate:.3f} | Bonf TPR @ alpha={alpha}: {bonf_rejection_rate:.3f}")
# Out:
# === TPR Experiment Summary ===
# nT=50: 1025 valid signal runs | Naive TPR @ alpha=0.05: 0.499 | Bonf TPR @ alpha=0.05: 0.000
# nT=75: 965 valid signal runs | Naive TPR @ alpha=0.05: 0.646 | Bonf TPR @ alpha=0.05: 0.000
# nT=100: 996 valid signal runs | Naive TPR @ alpha=0.05: 0.763 | Bonf TPR @ alpha=0.05: 0.000
